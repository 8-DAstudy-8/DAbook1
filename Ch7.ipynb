# %%
import matplotlib.pyplot as plt
xdata=[2,3,4,5]
ydata=[1,3,5,7]
plt.plot(xdata,ydata)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.title('Line Graph')
xdata=[2,3,4,5]
ydata=[1,3,5,7]
plt.plot(xdata,ydata)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.title('Legend')
data1=[2,3,4,5]
data2=[7,5,3,1]
plt.plot(data1, label='asc')
plt.plot(data2, label='desc')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
xdata=[2,4,6,8]
ydata=[1,3,5,7]
plt.plot(xdata, ydata, color='silver')
plt.show()

# %%
import matplotlib.pyplot as plt
xdata=[1,2,3,4]
ydata=[2,4,6,8]
plt.plot(xdata,ydata)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
import matplotlib.pyplot as plt
data1=[2,3,4,5]
data2=[1,3,5,7]
plt.plot(data1, color='orange', label='dashed', linestyle='--')
plt.plot(data2, color='green', label='dotted', linestyle=':')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.title('X Y range')
xdata=[2,4,6,8]
ydata=[1,3,5,7]
plt.plot(xdata, ydata, color='m', linestyle='-.', marker='o', markersize='10')
plt.xlim(0,25)
plt.ylim(-2,10)
plt.show()

# %%
import pandas as pd
my_score=[[50,90,95],[60,75,100],[75,85,90],[85,75,90],[95,80,85],[90,80,85],[95,80,75]]
subject=['kor','math','eng']
df=pd.DataFrame(my_score, columns=subject)
df.plot(kind='line')
# Out:
# <Axes: >

# %%
import pandas as pd
my_score=[[50,90,95],[60,75,100],[75,85,90],[85,75,90],[95,80,85],[90,80,85],[95,80,75]]
subject=['kor','math','eng']
df=pd.DataFrame(my_score, columns=subject)
df.plot(kind='area')
# Out:
# <Axes: >

# %%
import pandas as pd
my_score=[[50,90,95],[60,75,100],[75,85,90],[85,75,90],[95,80,85],[90,80,85],[95,80,75]]
subject=['kor','math','eng']
df=pd.DataFrame(my_score, columns=subject)
df.plot(kind='box')
# Out:
# <Axes: >

# %%
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_excel('fine_dust.xlsx', index_col='area') #data에 엑셀 파일 저장
data2018=data[2018]

# %%
plt.figure(figsize=(15,4))
plt.plot(data2018, color='m', marker='o')
plt.xlabel('area')
plt.ylabel('micrometer')
plt.title('2018 fine dust')
plt.grid() #격자 표시 활성
plt.show()

# %%
plt.figure(figsize=(10,4))

for year in range(2016,2020):
  chardata=data[year]
  plt.plot(chardata, marker='s', label=year)

plt.xlabel('area')
plt.ylabel('micrometer')
plt.title('2016~2019 fine dust')
plt.legend()
plt.grid()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_excel('fine_dust.xlsx', index_col='area')
data2017=data[2017]

plt.figure(figsize=(18,4))
plt.bar(data2017.index, data2017, color='orange')
plt.ylim(35,55)
plt.xlabel('area')
plt.ylabel('micrometer')
plt.title('2017 fine dust')
plt.grid()
plt.show()

# %%
import numpy as np
index=np.arange(4)

plt.figure(figsize=(18,4))

data4=data.loc['Gyeonggi':'Daegu', 2016:2019]
for year in range(2016,2020):
  chardata=data4[year]
  plt.bar(index, chardata, width=0.2, label=year)
  index=index+0.2

plt.ylim(35,55)
plt.xlabel('area')
plt.ylabel('micrometer')
plt.xticks(index-0.5, ['Gyeonggi','Incheon','Busan','Daegu'])
plt.title('2016~2019 fine dust')
plt.legend()
plt.grid()
plt.show()

# %%
#그룹 누적 막대 그래프
plt.figure(figsize=(10,4))
index=np.arange(4)

data4=data.loc['Gyeonggi':'Daegu', 2016:2019]
for year in range(2016,2020):
  chardata=data4[year]
  plt.barh(index, chardata, label=year)

plt.xlim(30,55)
plt.ylabel('area')
plt.xlabel('micrometer')
plt.yticks(index, ['Gyeonggi','Incheon','Busan','Daegu'])
plt.title('2016~2019 fine dust')
plt.legend()
plt.grid()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('health_screenings_2022_1000ea.CSV', encoding='cp949')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 30 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   기준년도         1000000 non-null  int64
#  1   가입자일련번호      1000000 non-null  int64
#  2   시도코드         1000000 non-null  int64
#  3   성별           1000000 non-null  int64
#  4   연령대코드(5세단위)  1000000 non-null  int64
#  5   신장(5cm단위)    1000000 non-null  int64
#  6   체중(5kg단위)    1000000 non-null  int64
#  7   허리둘레         999608 non-null   float64
#  8   시력(좌)        999814 non-null   float64
#  9   시력(우)        999815 non-null   float64
#  10  청력(좌)        999885 non-null   float64
#  11  청력(우)        999884 non-null   float64
#  12  수축기혈압        994444 non-null   float64
#  13  이완기혈압        994444 non-null   float64
#  14  식전혈당(공복혈당)   994389 non-null   float64
#  15  총콜레스테롤       345618 non-null   float64
#  16  트리글리세라이드     345614 non-null   float64
# ...

# %%
heightdata=data['신장(5cm단위)']
weightdata=data['체중(5kg단위)']

plt.figure(figsize=(10,4))
plt.scatter(heightdata,weightdata)

plt.xlabel('height')
plt.ylabel('weight')
plt.title('2022 scatter graph')
plt.grid()
plt.show()

# %%
systolic_data=data['수축기혈압']
diastolic_data=data['이완기혈압']
blood_sugar_data=data['식전혈당(공복혈당)']

plt.figure(figsize=(10,4))

plt.scatter(systolic_data, diastolic_data, color='m', edgecolor='black', label='systolic*diastolic')
plt.scatter(systolic_data, blood_sugar_data, color='g', edgecolor='black', label='systolic*blood_sugar')
plt.scatter(diastolic_data, blood_sugar_data, color='blue', edgecolor='black', label='diastolic*blood_sugar')

plt.xlim(40,180)
plt.ylim(30,300)
plt.title('2022 scatter graph')
plt.legend()
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
female_data=data.loc[data.성별==2,['성별','신장(5cm단위)']]

plt.figure(figsize=(10,6))
plt.hist(female_data['신장(5cm단위)'], bins=7, label='Female')

plt.xlim(130,180)
plt.xlabel('height')
plt.ylabel('frequency')
plt.title('2022 health screening histogram')
plt.legend()
plt.grid()
plt.show()

# %%
male_data=data.loc[data.성별==1,['성별','신장(5cm단위)']]
female_data=data.loc[data.성별==2,['성별','신장(5cm단위)']]

plt.figure(figsize=(10,6))
plt.hist(male_data['신장(5cm단위)'], bins=7, alpha=0.5, label='Male')
plt.hist(female_data['신장(5cm단위)'], bins=7, alpha=0.5, label='Female')

plt.xlim(130,200)
plt.xlabel('height')
plt.ylabel('frequency')
plt.title('2022 health screening histogram')
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np
height=np.array([male_data['신장(5cm단위)'], female_data['신장(5cm단위)']], dtype=object)

plt.figure(figsize=(10,6))
plt.hist(height, bins=6, label=['Male','Female'], stacked=True)

plt.xlim(130,200)
plt.xlabel('height')
plt.ylabel('frequency')
plt.title('2022 health screening histogram')
plt.legend()
plt.show()

# %%
import numpy as np
height=np.array([male_data['신장(5cm단위)'], female_data['신장(5cm단위)']], dtype=object)

plt.figure(figsize=(8,5))
plt.boxplot(height, labels=['Male','Female'])

plt.ylim(130,200)
plt.xlabel('gender')
plt.ylabel('height')
plt.title('2022 health screening histogram')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.boxplot(height, labels=['Male','Female'], vert=False)

plt.xlim(130,200)
plt.xlabel('gender')
plt.ylabel('height')
plt.title('2022 health screening histogram')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv('health_screenings_2022_1000ea.CSV', encoding='cp949')

# %%
data6=data.loc[:,['성별','신장(5cm단위)','체중(5kg단위)','허리둘레','음주여부','흡연상태']]
data6.loc[data6['성별']==1,['성별']]='Male'
data6.loc[data6['성별']==2,['성별']]='Female'
data6.loc[data6['음주여부']==0,['음주여부']]='Non-drinking'
data6.loc[data6['음주여부']==1,['음주여부']]='Drinking'
data6.loc[(data6['흡연상태']==1) | (data6['흡연상태']==2), ['흡연상태']]='Non-somking'
data6.loc[data6['흡연상태']==3,['흡연상태']]='Somking'

# %%
drinking=data6.groupby(['성별','음주여부'])['음주여부'].count()
smoking=data6.groupby(['성별','흡연상태'])['흡연상태'].count()
drinking=drinking.to_frame(name='count')
smoking=smoking.to_frame(name='count')
drinking=drinking.reset_index()
smoking=smoking.reset_index()

# %%
fig=plt.figure(figsize=(17,6))
fig.suptitle('2022 health screening', fontweight='bold')
index=np.arange(4)

fig.add_subplot(1,2,1)

plt.bar(index, drinking['count'])
plt.title('Drinking Type')
plt.ylabel('Count')
plt.xticks(index,['Non-drinking(Female)','Drinking(Female)', 'Non-drinking(Male)','Drinking(Male)'])

fig.add_subplot(1,2,2)

plt.bar(index, smoking['count'])
plt.title('Smoking Type')
plt.ylabel('Count')
plt.xticks(index,['Non-smoking(Female)','Smoking(Female)','Non-smoking(Male)','Smoking(Male)'])

plt.show()

# %%
fig=plt.figure(figsize=(17,6))

area1=fig.add_subplot(1,2,1)
area2=fig.add_subplot(1,2,2)

ax1=sns.barplot(data=drinking,x='성별',y='count',hue='음주여부',ax=area1)
ax2=sns.barplot(data=smoking,x='성별',y='count',hue='흡연상태',ax=area2)

fig.suptitle('2022 health screening', fontweight='bold')
area1.set_title('Drinking Type')
area2.set_title('Smoking Type')

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51020 (\N{HANGUL SYLLABLE EUM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
male_data=data6.loc[data6.성별=='Male',['성별','체중(5kg단위)','허리둘레','음주여부','흡연상태']]
female_data=data6.loc[data6.성별=='Female',['성별','체중(5kg단위)','허리둘레','음주여부','흡연상태']]

# %%
plt.figure(figsize=(10,5))
plt.title('Seaborn Strip Plot Graph')

sns.stripplot(data=male_data,x='허리둘레',y='체중(5kg단위)')
sns.stripplot(data=female_data,x='허리둘레',y='체중(5kg단위)')

plt.xticks(np.arange(0,127,63), labels=[53,90.5,128])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54728 (\N{HANGUL SYLLABLE HEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
plt.figure(figsize=(10,5))
plt.title('Seaborn Strip Plot Graph')

sns.stripplot(data=male_data,x='허리둘레',y='체중(5kg단위)', hue='성별', palette='pastel')
sns.stripplot(data=female_data,x='허리둘레',y='체중(5kg단위)', hue='성별', palette='Set1')

plt.xticks(np.arange(0,127,63), labels=[53,90.5,128])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54728 (\N{HANGUL SYLLABLE HEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
male_data_100=male_data.head(100)
female_data_100=female_data.head(100)

# %%
plt.figure(figsize=(10,5))
plt.title('Seaborn Swarm Plot Graph')

sns.swarmplot(data=male_data_100, x='허리둘레', y='체중(5kg단위)', hue='성별', palette='dark', size=4)
sns.swarmplot(data=female_data_100, x='허리둘레', y='체중(5kg단위)', hue='성별', palette='Set3', size=4)

plt.xticks(np.arange(0,46,22.5), labels=[53,75.5, 98])

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
plt.figure(figsize=(10,6))
sns.histplot(male_data['체중(5kg단위)'], bins=10, alpha=0.3, label='Male',color='orange')
sns.histplot(female_data['체중(5kg단위)'], bins=10, alpha=0.3, label='Female',color='green')

plt.xlim(20,130)
plt.xlabel('weight')
plt.ylabel('count')
plt.title('Weight Seaborn Histogram')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(male_data['허리둘레'],bins=30,alpha=0.3,label='Male',kde=True) #데이터에서 bins 값 조절해서 특징을 더 잘 드러내게 변경
sns.histplot(female_data['허리둘레'],bins=70,alpha=0.3,label='Female',color='m',kde=True)

plt.xlim(40,140)
plt.xlabel('waist')
plt.ylabel('count')
plt.title('Waist Seaborn Histogram')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.title('Drinking & Weight Box Plot')

sns.boxplot(data=data6, x='음주여부', y='체중(5kg단위)', hue='성별')
plt.ylim(30,100)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51020 (\N{HANGUL SYLLABLE EUM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
plt.figure(figsize=(10,7))
plt.title('Box Plot')

sns.boxplot(data=data6, x='허리둘레', y='음주여부', hue='성별', orient='h')
plt.xlim(50,110)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51020 (\N{HANGUL SYLLABLE EUM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54728 (\N{HANGUL SYLLABLE HEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
plt.figure(figsize=(10,7))
plt.title('Plot Graph')
sns.countplot(data=data6, x='음주여부',hue='성별')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51020 (\N{HANGUL SYLLABLE EUM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
data_100=data.head(100)

# %%
#이건 값이 안나오는데 왜 그런지?

plt.figure(figsize=(10,7))
plt.title('Plot Graph')
sns.countplot(data=data_100, y='흡연상태',hue='성별', order=['Smoking','Non-smoking'])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 55137 (\N{HANGUL SYLLABLE HEUB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
data_100.rename(columns={'체중(5kg단위)':'weight'}, inplace=True)
# Out:
# <ipython-input-111-9692f222e931>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_100.rename(columns={'체중(5kg단위)':'weight'}, inplace=True)

# %%
plt.figure(figsize=(10,7))
plt.title('Plot Graph')
sns.violinplot(data=data_100[data_100.weight<100], x='성별', y='weight', hue='음주여부')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51020 (\N{HANGUL SYLLABLE EUM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
plt.figure(figsize=(10,7))
plt.title('Plot Graph')
sns.violinplot(data=data6[data6.허리둘레<120], y='성별', x='허리둘레', hue='음주여부')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54728 (\N{HANGUL SYLLABLE HEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46168 (\N{HANGUL SYLLABLE DUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
data3=data.loc[:,['성별','체중(5kg단위)','허리둘레']]
data8=data.loc[:,['성별','체중(5kg단위)','허리둘레','음주여부','흡연상태','총콜레스테롤','HDL콜레스테롤','LDL콜레스테롤']]

# %%
plt.figure(figsize=(10,7))
plt.title('Heat Map')

correlation_data3=data3.corr()
sns.heatmap(correlation_data3, annot=True, cmap='coolwarm')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
plt.figure(figsize=(10,7))
plt.title('Heat Map')

correlation_data8=data8.corr()
upp_mat=np.triu(correlation_data8)

sns.heatmap(correlation_data8, annot=True, cmap='cool', mask=upp_mat)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
fg=sns.FacetGrid(data_100, col='음주여부', height=5, aspect=1.3)
fg.map(sns.histplot, '허리둘레', bins=7, color='g', kde=True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 51020 (\N{HANGUL SYLLABLE EUM}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 54728 (\N{HANGUL SYLLABLE HEO}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %%
fg=sns.FacetGrid(data_100, row='성별', col='음주여부', height=4.5, aspect=1.5)
fg.map(sns.histplot, '허리둘레', bins=7, color='g', kde=True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 51020 (\N{HANGUL SYLLABLE EUM}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %%
sns.pairplot(data6, height=3.3, aspect=1.3)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 49888 (\N{HANGUL SYLLABLE SIN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 54728 (\N{HANGUL SYLLABLE HEO}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %%
color=['#0000ff','#ff0000']
pp=sns.PairGrid(data6, hue='성별', palette=color, height=3.3, aspect=1.3)
pp.map_diag(sns.histplot, bins=10)
pp.map_offdiag(sns.scatterplot)
pp.add_legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv('health_screenings_2022_1000ea.CSV', encoding='cp949')
sampledata = data.sample(n=1000, random_state=42)

#sampledata.info()

data3=sampledata.loc[:,['시도코드','성별','허리둘레']]

male_data=data3[data3['성별']==1].groupby('시도코드')['허리둘레'].mean()
female_data=data3[data3['성별']==2].groupby('시도코드')['허리둘레'].mean()

plt.figure(figsize=(12,4))

plt.plot(male_data, marker='o', label='Male')
plt.plot(female_data, marker='o', label='Female')

plt.xlabel('count')
plt.ylabel('waist')
plt.title('2022 health screening')
plt.legend()
plt.grid()
plt.show()

# %%
data3=sampledata.loc[:,['시도코드','성별','허리둘레']]
data3
print(data3.index)
data3.shape
# Out:
# Index([987231,  79954, 567130, 500891,  55399, 135049, 733378, 732057,  51333,
#        731479,
#        ...
#        849695, 321776,  49982, 758444, 154449, 914398, 189053,  47977, 600785,
#         67400],
#       dtype='int64', length=1000)
# (1000, 3)

# %%
#그래프 안그려지는데 어떻게 그렸는지?
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data3=sampledata.loc[:,['시도코드','성별','허리둘레']]
#인덱스가 정수 범위로 이루어진 것이 아닌 특정 값들로 이루어져있어서 범위를 조정해도 불가능하다
#
waistData=data3.loc[:,['허리둘레']]

plt.figure(figsize=(10,5))

bins = np.arange(50, 115, 5)
waistData['bin'] = pd.cut(waistData['허리둘레'], bins=bins, right=False)
waist_counts = waistData['bin'].value_counts().sort_index()

# 막대 그래프 그리기
plt.figure(figsize=(10, 5))
waist_counts.plot(kind='bar', color='blue', edgecolor='black')

plt.ylim(50,110)
plt.xlabel('Count')
plt.ylabel('Waist')
plt.title('2022 health screening')
plt.grid()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv('health_screenings_2022_1000ea.CSV', encoding='cp949')
lEyeData=data['시력(좌)']
rEyeData=data['시력(우)']

plt.figure(figsize=(5,5))

plt.xlim(0,2.5)
plt.ylim(0,2.5)
plt.xlabel('Eye Left')
plt.ylabel('Eye Right')
plt.title('2022 health screening')
plt.scatter(lEyeData, rEyeData)
plt.grid()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv('health_screenings_2022_1000ea.CSV', encoding='cp949')
data3=data.loc[:,['시도코드','성별','허리둘레']]

male_data=data3.loc[data3.성별==1,['성별','허리둘레']]
female_data=data3.loc[data3.성별==2,['성별','허리둘레']]

plt.figure(figsize=(10,6))
sns.histplot(male_data['허리둘레'], bins=20, alpha=0.3, label='Male',color='orange')
sns.histplot(female_data['허리둘레'], bins=70, alpha=0.3, label='Female',color='green')


plt.xlim(50,115)
plt.xlabel('Waist')
plt.ylabel('Frequency')
plt.title('2022 health screening')
plt.legend()
plt.grid()
plt.show()

# %%
#박스가 안그려지는데 왜 안그려지는지
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv('health_screenings_2022_1000ea.CSV', encoding='cp949')
data3=data.loc[:,['시도코드','성별','허리둘레']]

mandata=data3.loc[data3.성별==1,['성별','허리둘레']]
womandata=data3.loc[data3.성별==2,['성별','허리둘레']]

#male=np.array(male_data['허리둘레'], dtype=object)
#female=np.array(male_data['허리둘레'])

combined_data = pd.concat([mandata, womandata])

#array를 합쳐야 될 것 같은데

plt.figure(figsize=(8,5))
sns.boxplot(data=combined_data, x='성별', y='허리둘레')
plt.ylim(130,200)
plt.xlabel('gender')
plt.ylabel('waist')
plt.title('2022 health screening histogram')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv('health_screenings_2022_1000ea.CSV', encoding='cp949')
data6=data.loc[:,['성별','신장(5cm단위)','체중(5kg단위)','허리둘레','음주여부','흡연상태']]

data6.loc[data6['성별']==1,['성별']]='Male'
data6.loc[data6['성별']==2,['성별']]='Female'
data6.loc[(data6['흡연상태']==1) | (data6['흡연상태']==2),['흡연상태']]='Non-smoking'
data6.loc[data6['흡연상태']==3,['흡연상태']]='Smoking'

smoking=data6.groupby(['성별','흡연상태'])['흡연상태'].count()
smoking=smoking.to_frame(name='count')
smoking=smoking.reset_index()

plt.figure(figsize=(10,6))

plt.title('Plot Graph')
sns.countplot(data=data6, x='흡연상태',hue='성별')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 55137 (\N{HANGUL SYLLABLE HEUB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
plt.figure(figsize=(10,7))
plt.title('Plot Graph')
sns.violinplot(data=data6, x='성별', y='체중(5kg단위)', hue='흡연상태')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv('health_screenings_2022_1000ea.CSV', encoding='cp949')
data6=data.loc[:,['성별','신장(5cm단위)','체중(5kg단위)','허리둘레','음주여부','흡연상태']]

plt.figure(figsize=(10,6))

correlation_data6=data6.corr()
upp_mat=np.triu(correlation_data6)

sns.heatmap(correlation_data6, annot=True, cmap='plasma', mask=upp_mat)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 49888 (\N{HANGUL SYLLABLE SIN}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.draw()
# ...
