# %%
import pandas as pd

from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

cancer=load_breast_cancer()

data_df=pd.DataFrame(cancer.data, columns=cancer.feature_names)
data_df.head(4)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
#
# [4 rows x 30 columns]

# %%
lr_clf=LogisticRegression(solver='liblinear')
knn_clf=KNeighborsClassifier(n_neighbors=8)

vo_clf=VotingClassifier(estimators=[('LR', lr_clf), ('KNN',knn_clf)],voting='soft')

X_train, X_test, y_train, y_test=train_test_split(cancer.data, cancer.target, test_size=0.2, random_state=156)

vo_clf.fit(X_train, y_train)
pred=vo_clf.predict(X_test)
print('Voting 분류기 정확도: {0:.4f}'.format(accuracy_score(y_test,pred)))

classifiers=[lr_clf,knn_clf]
for classifier in classifiers:
  classifier.fit(X_train, y_train)
  pred=classifier.predict(X_test)
  class_name=classifier.__class__.__name__
  print('{0} 정확도: {1:4f}'.format(class_name, accuracy_score(y_test, pred)))
# Out:
# Voting 분류기 정확도: 0.9561
# LogisticRegression 정확도: 0.947368
# KNeighborsClassifier 정확도: 0.938596

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import GridSearchCV

params={
    'max_depth':[8,16,24],
    'min_samples_leaf':[1,6,12],
    'min_samples_split':[2,8,16]
}

rf_clf=RandomForestClassifier(n_estimators=100, random_state=0, n_jobs=-1)
grid_cv=GridSearchCV(rf_clf, param_grid=params,cv=2, n_jobs=-1)
grid_cv.fit(X_train,y_train)

print('최적 하이퍼파라미터:\n', grid_cv.best_params_)
print('최고 예측 정확도:{0:.4f}'.format(grid_cv.best_score_))
# Out:
# 최적 하이퍼파라미터:
#  {'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 최고 예측 정확도:0.9627

# %%
rf_clf1=RandomForestClassifier(n_estimators=100, min_samples_leaf=6,max_depth=16, min_samples_split=2, random_state=0)
rf_clf1.fit(X_train, y_train)
pred=rf_clf1.predict(X_test)
print('예측 정확도: {0:.4f}'.format(accuracy_score(y_test, pred)))
# Out:
# 예측 정확도: 0.9474

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

ftr_importances_values=rf_clf1.feature_importances_
ftr_importances=pd.Series(ftr_importances_values, index=X_train.columns)
ftr_top20=ftr_importances.sort_values(ascending=False)[:20]

plt.figure(figsize=(8,6))
plt.title('Feature importances Top 20')
sns.barplot(x=ftr_top20, y=ftr_top20.index)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-9a9e29f4ceae> in <cell line: 6>()
#       4
#       5 ftr_importances_values=rf_clf1.feature_importances_
# ----> 6 ftr_importances=pd.Series(ftr_importances_values, index=X_train.columns)
#       7 ftr_top20=ftr_importances.sort_values(ascending=False)[:20]
#       8
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
pip install xgboost==1.5.0
# Out:
# Collecting xgboost==1.5.0
#   Downloading xgboost-1.5.0-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost==1.5.0) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost==1.5.0) (1.13.1)
# Downloading xgboost-1.5.0-py3-none-manylinux2014_x86_64.whl (173.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.5/173.5 MB 5.3 MB/s eta 0:00:00
# Installing collected packages: xgboost
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.1.0
#     Uninstalling xgboost-2.1.0:
#       Successfully uninstalled xgboost-2.1.0
# Successfully installed xgboost-1.5.0

# %%
import xgboost as xgb
from xgboost import plot_importance
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

dataset=load_breast_cancer()
features=dataset.data
labels=dataset.target

cancer_df=pd.DataFrame(data=features,columns=dataset.feature_names)
cancer_df['target']=labels
cancer_df.head(3)
# Out:
#    mean radius  mean texture  mean perimeter  ...  worst symmetry  worst fractal dimension  target
# 0        17.99         10.38           122.8  ...          0.4601                  0.11890       0
# 1        20.57         17.77           132.9  ...          0.2750                  0.08902       0
# 2        19.69         21.25           130.0  ...          0.3613                  0.08758       0
#
# [3 rows x 31 columns]

# %%
print(dataset.target_names)
print(cancer_df['target'].value_counts())
# Out:
# ['malignant' 'benign']
# 1    357
# 0    212
# Name: target, dtype: int64

# %%
X_features=cancer_df.iloc[:,:-1]
y_label=cancer_df.iloc[:,-1]

X_train,X_test, y_train, y_test=train_test_split(X_features, y_label, test_size=0.2, random_state=156)

X_tr,X_val, y_tr,y_val= train_test_split(X_train, y_train, test_size=0.1, random_state=156)

print(X_train.shape, X_test.shape)
print(X_tr.shape, X_val.shape)
# Out:
# (455, 30) (114, 30)
# (409, 30) (46, 30)

# %%
# !pip install pandas==1.3.3
# Out:
# Collecting pandas==1.3.3
#   Downloading pandas-1.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from pandas==1.3.3) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.10/dist-packages (from pandas==1.3.3) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.10/dist-packages (from pandas==1.3.3) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.3) (1.16.0)
# Downloading pandas-1.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 29.6 MB/s eta 0:00:00
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# arviz 0.18.0 requires pandas>=1.5.0, but you have pandas 1.3.3 which is incompatible.
# bigframes 1.11.1 requires pandas>=1.5.0, but you have pandas 1.3.3 which is incompatible.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 1.3.3 which is incompatible.
# geopandas 0.14.4 requires pandas>=1.4.0, but you have pandas 1.3.3 which is incompatible.
# google-colab 1.0.0 requires pandas==2.1.4, but you have pandas 1.3.3 which is incompatible.
# mizani 0.9.3 requires pandas>=1.3.5, but you have pandas 1.3.3 which is incompatible.
# plotnine 0.12.4 requires pandas>=1.5.0, but you have pandas 1.3.3 which is incompatible.
# statsmodels 0.14.2 requires pandas!=2.1.0,>=1.4, but you have pandas 1.3.3 which is incompatible.
# xarray 2024.6.0 requires pandas>=2.0, but you have pandas 1.3.3 which is incompatible.
# Successfully installed pandas-1.3.3

# %%
pip install xgboost==1.5.0
# Out:
# Collecting xgboost==1.5.0
#   Using cached xgboost-1.5.0-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost==1.5.0) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost==1.5.0) (1.13.1)
# Using cached xgboost-1.5.0-py3-none-manylinux2014_x86_64.whl (173.5 MB)
# Installing collected packages: xgboost
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.1.1
#     Uninstalling xgboost-2.1.1:
#       Successfully uninstalled xgboost-2.1.1
# Successfully installed xgboost-1.5.0

# %%
dtr=xgb.DMatrix(data=X_tr, label=y_tr)
dval=xgb.DMatrix(data=X_val, label=y_val)
dtest=xgb.DMatrix(data=X_test, label=y_test)

# %%
params={ 'max_depth':3,
        'eta':0.05,
         'objective':'binary:logistic',
         'eval_metric':'logloss'
         }
num_rounds=400

# %%
eval_list=[(dtr,'train'),(dval,'eval')]
xgb_model=xgb.train(params=params, dtrain=dtr, num_boost_round=num_rounds, \
                    early_stopping_rounds=50, evals=eval_list)
# Out:
# [0]	train-logloss:0.65016	eval-logloss:0.66183
# [1]	train-logloss:0.61131	eval-logloss:0.63609
# [2]	train-logloss:0.57563	eval-logloss:0.61144
# [3]	train-logloss:0.54310	eval-logloss:0.59204
# [4]	train-logloss:0.51323	eval-logloss:0.57329
# [5]	train-logloss:0.48447	eval-logloss:0.55037
# [6]	train-logloss:0.45796	eval-logloss:0.52929
# [7]	train-logloss:0.43436	eval-logloss:0.51534
# [8]	train-logloss:0.41150	eval-logloss:0.49718
# [9]	train-logloss:0.39027	eval-logloss:0.48154
# [10]	train-logloss:0.37128	eval-logloss:0.46990
# [11]	train-logloss:0.35254	eval-logloss:0.45474
# [12]	train-logloss:0.33528	eval-logloss:0.44229
# [13]	train-logloss:0.31893	eval-logloss:0.42961
# [14]	train-logloss:0.30439	eval-logloss:0.42065
# [15]	train-logloss:0.29000	eval-logloss:0.40958
# [16]	train-logloss:0.27651	eval-logloss:0.39887
# [17]	train-logloss:0.26389	eval-logloss:0.39050
# [18]	train-logloss:0.25210	eval-logloss:0.38254
# [19]	train-logloss:0.24123	eval-logloss:0.37393
# [20]	train-logloss:0.23076	eval-logloss:0.36789
# [21]	train-logloss:0.22091	eval-logloss:0.36017
# [22]	train-logloss:0.21155	eval-logloss:0.35421
# [23]	train-logloss:0.20263	eval-logloss:0.34683
# [24]	train-logloss:0.19434	eval-logloss:0.34111
# [25]	train-logloss:0.18637	eval-logloss:0.33634
# [26]	train-logloss:0.17875	eval-logloss:0.33082
# [27]	train-logloss:0.17167	eval-logloss:0.32675
# [28]	train-logloss:0.16481	eval-logloss:0.32099
# [29]	train-logloss:0.15835	eval-logloss:0.31671
# [30]	train-logloss:0.15225	eval-logloss:0.31277
# [31]	train-logloss:0.14650	eval-logloss:0.30882
# [32]	train-logloss:0.14102	eval-logloss:0.30437
# [33]	train-logloss:0.13590	eval-logloss:0.30103
# [34]	train-logloss:0.13109	eval-logloss:0.29794
# [35]	train-logloss:0.12647	eval-logloss:0.29499
# [36]	train-logloss:0.12197	eval-logloss:0.29295
# [37]	train-logloss:0.11784	eval-logloss:0.29043
# [38]	train-logloss:0.11379	eval-logloss:0.28927
# [39]	train-logloss:0.10994	eval-logloss:0.28578
# [40]	train-logloss:0.10638	eval-logloss:0.28364
# [41]	train-logloss:0.10302	eval-logloss:0.28183
# [42]	train-logloss:0.09963	eval-logloss:0.28005
# [43]	train-logloss:0.09649	eval-logloss:0.27972
# [44]	train-logloss:0.09359	eval-logloss:0.27744
# [45]	train-logloss:0.09080	eval-logloss:0.27542
# [46]	train-logloss:0.08807	eval-logloss:0.27504
# [47]	train-logloss:0.08541	eval-logloss:0.27458
# [48]	train-logloss:0.08299	eval-logloss:0.27348
# [49]	train-logloss:0.08035	eval-logloss:0.27247
# [50]	train-logloss:0.07786	eval-logloss:0.27163
# [51]	train-logloss:0.07550	eval-logloss:0.27094
# [52]	train-logloss:0.07344	eval-logloss:0.26967
# [53]	train-logloss:0.07147	eval-logloss:0.27008
# [54]	train-logloss:0.06964	eval-logloss:0.26890
# [55]	train-logloss:0.06766	eval-logloss:0.26854
# [56]	train-logloss:0.06592	eval-logloss:0.26900
# [57]	train-logloss:0.06433	eval-logloss:0.26790
# [58]	train-logloss:0.06259	eval-logloss:0.26663
# [59]	train-logloss:0.06107	eval-logloss:0.26743
# [60]	train-logloss:0.05957	eval-logloss:0.26610
# [61]	train-logloss:0.05817	eval-logloss:0.26644
# [62]	train-logloss:0.05691	eval-logloss:0.26673
# [63]	train-logloss:0.05550	eval-logloss:0.26550
# [64]	train-logloss:0.05422	eval-logloss:0.26443
# [65]	train-logloss:0.05311	eval-logloss:0.26500
# [66]	train-logloss:0.05207	eval-logloss:0.26591
# [67]	train-logloss:0.05093	eval-logloss:0.26501
# [68]	train-logloss:0.04976	eval-logloss:0.26435
# [69]	train-logloss:0.04872	eval-logloss:0.26360
# [70]	train-logloss:0.04776	eval-logloss:0.26319
# [71]	train-logloss:0.04680	eval-logloss:0.26255
# [72]	train-logloss:0.04580	eval-logloss:0.26204
# [73]	train-logloss:0.04484	eval-logloss:0.26254
# [74]	train-logloss:0.04388	eval-logloss:0.26289
# [75]	train-logloss:0.04309	eval-logloss:0.26249
# [76]	train-logloss:0.04224	eval-logloss:0.26217
# [77]	train-logloss:0.04133	eval-logloss:0.26166
# [78]	train-logloss:0.04050	eval-logloss:0.26179
# [79]	train-logloss:0.03967	eval-logloss:0.26103
# [80]	train-logloss:0.03877	eval-logloss:0.26094
# [81]	train-logloss:0.03806	eval-logloss:0.26148
# [82]	train-logloss:0.03740	eval-logloss:0.26054
# [83]	train-logloss:0.03676	eval-logloss:0.25967
# [84]	train-logloss:0.03605	eval-logloss:0.25905
# [85]	train-logloss:0.03545	eval-logloss:0.26007
# [86]	train-logloss:0.03488	eval-logloss:0.25984
# [87]	train-logloss:0.03425	eval-logloss:0.25933
# [88]	train-logloss:0.03361	eval-logloss:0.25932
# [89]	train-logloss:0.03311	eval-logloss:0.26002
# [90]	train-logloss:0.03260	eval-logloss:0.25936
# [91]	train-logloss:0.03202	eval-logloss:0.25886
# [92]	train-logloss:0.03152	eval-logloss:0.25918
# [93]	train-logloss:0.03107	eval-logloss:0.25865
# [94]	train-logloss:0.03049	eval-logloss:0.25951
# [95]	train-logloss:0.03007	eval-logloss:0.26091
# [96]	train-logloss:0.02963	eval-logloss:0.26014
# [97]	train-logloss:0.02913	eval-logloss:0.25974
# [98]	train-logloss:0.02866	eval-logloss:0.25937
# [99]	train-logloss:0.02829	eval-logloss:0.25893
# [100]	train-logloss:0.02789	eval-logloss:0.25928
# [101]	train-logloss:0.02751	eval-logloss:0.25955
# [102]	train-logloss:0.02714	eval-logloss:0.25901
# [103]	train-logloss:0.02668	eval-logloss:0.25991
# [104]	train-logloss:0.02634	eval-logloss:0.25950
# [105]	train-logloss:0.02594	eval-logloss:0.25924
# [106]	train-logloss:0.02556	eval-logloss:0.25901
# [107]	train-logloss:0.02522	eval-logloss:0.25738
# [108]	train-logloss:0.02492	eval-logloss:0.25702
# [109]	train-logloss:0.02453	eval-logloss:0.25789
# [110]	train-logloss:0.02418	eval-logloss:0.25770
# [111]	train-logloss:0.02384	eval-logloss:0.25842
# [112]	train-logloss:0.02356	eval-logloss:0.25810
# [113]	train-logloss:0.02322	eval-logloss:0.25848
# [114]	train-logloss:0.02290	eval-logloss:0.25833
# [115]	train-logloss:0.02260	eval-logloss:0.25820
# [116]	train-logloss:0.02229	eval-logloss:0.25905
# [117]	train-logloss:0.02204	eval-logloss:0.25878
# [118]	train-logloss:0.02176	eval-logloss:0.25728
# [119]	train-logloss:0.02149	eval-logloss:0.25722
# [120]	train-logloss:0.02119	eval-logloss:0.25764
# [121]	train-logloss:0.02095	eval-logloss:0.25761
# [122]	train-logloss:0.02067	eval-logloss:0.25832
# [123]	train-logloss:0.02045	eval-logloss:0.25808
# [124]	train-logloss:0.02023	eval-logloss:0.25855
# [125]	train-logloss:0.01998	eval-logloss:0.25714
# [126]	train-logloss:0.01973	eval-logloss:0.25587
# [127]	train-logloss:0.01946	eval-logloss:0.25640
# [128]	train-logloss:0.01927	eval-logloss:0.25685
# [129]	train-logloss:0.01908	eval-logloss:0.25665
# [130]	train-logloss:0.01886	eval-logloss:0.25712
# [131]	train-logloss:0.01863	eval-logloss:0.25609
# [132]	train-logloss:0.01839	eval-logloss:0.25649
# [133]	train-logloss:0.01816	eval-logloss:0.25789
# [134]	train-logloss:0.01802	eval-logloss:0.25811
# [135]	train-logloss:0.01785	eval-logloss:0.25794
# [136]	train-logloss:0.01763	eval-logloss:0.25876
# [137]	train-logloss:0.01748	eval-logloss:0.25884
# [138]	train-logloss:0.01732	eval-logloss:0.25867
# [139]	train-logloss:0.01719	eval-logloss:0.25876
# [140]	train-logloss:0.01696	eval-logloss:0.25987
# [141]	train-logloss:0.01681	eval-logloss:0.25960
# [142]	train-logloss:0.01669	eval-logloss:0.25982
# [143]	train-logloss:0.01656	eval-logloss:0.25992
# [144]	train-logloss:0.01638	eval-logloss:0.26035
# [145]	train-logloss:0.01623	eval-logloss:0.26055
# [146]	train-logloss:0.01606	eval-logloss:0.26092
# [147]	train-logloss:0.01589	eval-logloss:0.26137
# [148]	train-logloss:0.01572	eval-logloss:0.25999
# [149]	train-logloss:0.01557	eval-logloss:0.26028
# [150]	train-logloss:0.01546	eval-logloss:0.26048
# [151]	train-logloss:0.01531	eval-logloss:0.26142
# [152]	train-logloss:0.01515	eval-logloss:0.26188
# [153]	train-logloss:0.01501	eval-logloss:0.26227
# [154]	train-logloss:0.01486	eval-logloss:0.26287
# [155]	train-logloss:0.01476	eval-logloss:0.26299
# [156]	train-logloss:0.01461	eval-logloss:0.26346
# [157]	train-logloss:0.01448	eval-logloss:0.26379
# [158]	train-logloss:0.01434	eval-logloss:0.26306
# [159]	train-logloss:0.01424	eval-logloss:0.26237
# [160]	train-logloss:0.01410	eval-logloss:0.26251
# [161]	train-logloss:0.01401	eval-logloss:0.26265
# [162]	train-logloss:0.01392	eval-logloss:0.26264
# [163]	train-logloss:0.01380	eval-logloss:0.26250
# [164]	train-logloss:0.01372	eval-logloss:0.26264
# [165]	train-logloss:0.01359	eval-logloss:0.26255
# [166]	train-logloss:0.01350	eval-logloss:0.26188
# [167]	train-logloss:0.01342	eval-logloss:0.26203
# [168]	train-logloss:0.01331	eval-logloss:0.26190
# [169]	train-logloss:0.01319	eval-logloss:0.26184
# [170]	train-logloss:0.01312	eval-logloss:0.26133
# [171]	train-logloss:0.01304	eval-logloss:0.26148
# [172]	train-logloss:0.01297	eval-logloss:0.26157
# [173]	train-logloss:0.01285	eval-logloss:0.26253
# [174]	train-logloss:0.01278	eval-logloss:0.26229
# [175]	train-logloss:0.01267	eval-logloss:0.26086
# [176]	train-logloss:0.01258	eval-logloss:0.26103

# %%
pred_probs=xgb_model.predict(dtest)
print('predict() 수행 결괏값을 10개만 표시, 예측 확률 값으로 표시 됨')
print(np.round(pred_probs[:10],3))

preds=[1 if x>0.5 else 0 for x in pred_probs]
print('예측값 10개만 표시: ',preds[:10])
# Out:
# predict() 수행 결괏값을 10개만 표시, 예측 확률 값으로 표시 됨
# [0.845 0.008 0.68  0.081 0.975 0.999 0.998 0.998 0.996 0.001]
# 예측값 10개만 표시:  [1, 0, 1, 0, 1, 1, 1, 1, 1, 0]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig,ax=plt.subplots(figsize=(10,12))
plot_importance(xgb_model,ax=ax)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
from xgboost import XGBClassifier
xgb_wrapper=XGBClassifier(n_estimators=400, learning_rate=0.05, max_depth=3, eval_metric='logloss')
xgb_wrapper.fit(X_train, y_train, verbose=True)
w_preds=xgb_wrapper.predict(X_test)
w_pred_proba=xgb_wrapper.predict_proba(X_test)[:,1]

# %%
from xgboost import XGBClassifier

xgb_wrapper=XGBClassifier(n_estimators=400, learning_rate=0.05, max_depth=3)
evals=[(X_tr, y_tr),(X_val, y_val)]
xgb_wrapper.fit(X_tr, y_tr, early_stopping_rounds=50, eval_metric="logloss", eval_set=evals, verbose=True)
ws50_preds=xgb_wrapper.predict(X_test)
ws50_pred_proba=xgb_wrapper.predict_proba(X_test)[:,1]
# Out:
# [0]	validation_0-logloss:0.65016	validation_1-logloss:0.66183
# [1]	validation_0-logloss:0.61131	validation_1-logloss:0.63609
# [2]	validation_0-logloss:0.57563	validation_1-logloss:0.61144
# [3]	validation_0-logloss:0.54310	validation_1-logloss:0.59204
# [4]	validation_0-logloss:0.51323	validation_1-logloss:0.57329
# [5]	validation_0-logloss:0.48447	validation_1-logloss:0.55037
# [6]	validation_0-logloss:0.45796	validation_1-logloss:0.52929
# [7]	validation_0-logloss:0.43436	validation_1-logloss:0.51534
# [8]	validation_0-logloss:0.41150	validation_1-logloss:0.49718
# [9]	validation_0-logloss:0.39027	validation_1-logloss:0.48154
# [10]	validation_0-logloss:0.37128	validation_1-logloss:0.46990
# [11]	validation_0-logloss:0.35254	validation_1-logloss:0.45474
# [12]	validation_0-logloss:0.33528	validation_1-logloss:0.44229
# [13]	validation_0-logloss:0.31893	validation_1-logloss:0.42961
# [14]	validation_0-logloss:0.30439	validation_1-logloss:0.42065
# [15]	validation_0-logloss:0.29000	validation_1-logloss:0.40958
# [16]	validation_0-logloss:0.27651	validation_1-logloss:0.39887
# [17]	validation_0-logloss:0.26389	validation_1-logloss:0.39050
# [18]	validation_0-logloss:0.25210	validation_1-logloss:0.38254
# [19]	validation_0-logloss:0.24123	validation_1-logloss:0.37393
# [20]	validation_0-logloss:0.23076	validation_1-logloss:0.36789
# [21]	validation_0-logloss:0.22091	validation_1-logloss:0.36017
# [22]	validation_0-logloss:0.21155	validation_1-logloss:0.35421
# [23]	validation_0-logloss:0.20263	validation_1-logloss:0.34683
# [24]	validation_0-logloss:0.19434	validation_1-logloss:0.34111
# [25]	validation_0-logloss:0.18637	validation_1-logloss:0.33634
# [26]	validation_0-logloss:0.17875	validation_1-logloss:0.33082
# [27]	validation_0-logloss:0.17167	validation_1-logloss:0.32675
# [28]	validation_0-logloss:0.16481	validation_1-logloss:0.32099
# [29]	validation_0-logloss:0.15835	validation_1-logloss:0.31671
# [30]	validation_0-logloss:0.15225	validation_1-logloss:0.31277
# [31]	validation_0-logloss:0.14650	validation_1-logloss:0.30882
# [32]	validation_0-logloss:0.14102	validation_1-logloss:0.30437
# [33]	validation_0-logloss:0.13590	validation_1-logloss:0.30103
# [34]	validation_0-logloss:0.13109	validation_1-logloss:0.29794
# [35]	validation_0-logloss:0.12647	validation_1-logloss:0.29499
# [36]	validation_0-logloss:0.12197	validation_1-logloss:0.29295
# [37]	validation_0-logloss:0.11784	validation_1-logloss:0.29043
# [38]	validation_0-logloss:0.11379	validation_1-logloss:0.28927
# [39]	validation_0-logloss:0.10994	validation_1-logloss:0.28578
# [40]	validation_0-logloss:0.10638	validation_1-logloss:0.28364
# [41]	validation_0-logloss:0.10302	validation_1-logloss:0.28183
# [42]	validation_0-logloss:0.09963	validation_1-logloss:0.28005
# [43]	validation_0-logloss:0.09649	validation_1-logloss:0.27972
# [44]	validation_0-logloss:0.09359	validation_1-logloss:0.27744
# [45]	validation_0-logloss:0.09080	validation_1-logloss:0.27542
# [46]	validation_0-logloss:0.08807	validation_1-logloss:0.27504
# [47]	validation_0-logloss:0.08541	validation_1-logloss:0.27458
# [48]	validation_0-logloss:0.08299	validation_1-logloss:0.27348
# [49]	validation_0-logloss:0.08035	validation_1-logloss:0.27247
# [50]	validation_0-logloss:0.07786	validation_1-logloss:0.27163
# [51]	validation_0-logloss:0.07550	validation_1-logloss:0.27094
# [52]	validation_0-logloss:0.07344	validation_1-logloss:0.26967
# [53]	validation_0-logloss:0.07147	validation_1-logloss:0.27008
# [54]	validation_0-logloss:0.06964	validation_1-logloss:0.26890
# [55]	validation_0-logloss:0.06766	validation_1-logloss:0.26854
# [56]	validation_0-logloss:0.06592	validation_1-logloss:0.26900
# [57]	validation_0-logloss:0.06433	validation_1-logloss:0.26790
# [58]	validation_0-logloss:0.06259	validation_1-logloss:0.26663
# [59]	validation_0-logloss:0.06107	validation_1-logloss:0.26743
# [60]	validation_0-logloss:0.05957	validation_1-logloss:0.26610
# [61]	validation_0-logloss:0.05817	validation_1-logloss:0.26644
# [62]	validation_0-logloss:0.05691	validation_1-logloss:0.26673
# [63]	validation_0-logloss:0.05550	validation_1-logloss:0.26550
# [64]	validation_0-logloss:0.05422	validation_1-logloss:0.26443
# [65]	validation_0-logloss:0.05311	validation_1-logloss:0.26500
# [66]	validation_0-logloss:0.05207	validation_1-logloss:0.26591
# [67]	validation_0-logloss:0.05093	validation_1-logloss:0.26501
# [68]	validation_0-logloss:0.04976	validation_1-logloss:0.26435
# [69]	validation_0-logloss:0.04872	validation_1-logloss:0.26360
# [70]	validation_0-logloss:0.04776	validation_1-logloss:0.26319
# [71]	validation_0-logloss:0.04680	validation_1-logloss:0.26255
# [72]	validation_0-logloss:0.04580	validation_1-logloss:0.26204
# [73]	validation_0-logloss:0.04484	validation_1-logloss:0.26254
# [74]	validation_0-logloss:0.04388	validation_1-logloss:0.26289
# [75]	validation_0-logloss:0.04309	validation_1-logloss:0.26249
# [76]	validation_0-logloss:0.04224	validation_1-logloss:0.26217
# [77]	validation_0-logloss:0.04133	validation_1-logloss:0.26166
# [78]	validation_0-logloss:0.04050	validation_1-logloss:0.26179
# [79]	validation_0-logloss:0.03967	validation_1-logloss:0.26103
# [80]	validation_0-logloss:0.03877	validation_1-logloss:0.26094
# [81]	validation_0-logloss:0.03806	validation_1-logloss:0.26148
# [82]	validation_0-logloss:0.03740	validation_1-logloss:0.26054
# [83]	validation_0-logloss:0.03676	validation_1-logloss:0.25967
# [84]	validation_0-logloss:0.03605	validation_1-logloss:0.25905
# [85]	validation_0-logloss:0.03545	validation_1-logloss:0.26007
# [86]	validation_0-logloss:0.03488	validation_1-logloss:0.25984
# [87]	validation_0-logloss:0.03425	validation_1-logloss:0.25933
# [88]	validation_0-logloss:0.03361	validation_1-logloss:0.25932
# [89]	validation_0-logloss:0.03311	validation_1-logloss:0.26002
# [90]	validation_0-logloss:0.03260	validation_1-logloss:0.25936
# [91]	validation_0-logloss:0.03202	validation_1-logloss:0.25886
# [92]	validation_0-logloss:0.03152	validation_1-logloss:0.25918
# [93]	validation_0-logloss:0.03107	validation_1-logloss:0.25865
# [94]	validation_0-logloss:0.03049	validation_1-logloss:0.25951
# [95]	validation_0-logloss:0.03007	validation_1-logloss:0.26091
# [96]	validation_0-logloss:0.02963	validation_1-logloss:0.26014
# [97]	validation_0-logloss:0.02913	validation_1-logloss:0.25974
# [98]	validation_0-logloss:0.02866	validation_1-logloss:0.25937
# [99]	validation_0-logloss:0.02829	validation_1-logloss:0.25893
# [100]	validation_0-logloss:0.02789	validation_1-logloss:0.25928
# [101]	validation_0-logloss:0.02751	validation_1-logloss:0.25955
# [102]	validation_0-logloss:0.02714	validation_1-logloss:0.25901
# [103]	validation_0-logloss:0.02668	validation_1-logloss:0.25991
# [104]	validation_0-logloss:0.02634	validation_1-logloss:0.25950
# [105]	validation_0-logloss:0.02594	validation_1-logloss:0.25924
# [106]	validation_0-logloss:0.02556	validation_1-logloss:0.25901
# [107]	validation_0-logloss:0.02522	validation_1-logloss:0.25738
# [108]	validation_0-logloss:0.02492	validation_1-logloss:0.25702
# [109]	validation_0-logloss:0.02453	validation_1-logloss:0.25789
# [110]	validation_0-logloss:0.02418	validation_1-logloss:0.25770
# [111]	validation_0-logloss:0.02384	validation_1-logloss:0.25842
# [112]	validation_0-logloss:0.02356	validation_1-logloss:0.25810
# [113]	validation_0-logloss:0.02322	validation_1-logloss:0.25848
# [114]	validation_0-logloss:0.02290	validation_1-logloss:0.25833
# [115]	validation_0-logloss:0.02260	validation_1-logloss:0.25820
# [116]	validation_0-logloss:0.02229	validation_1-logloss:0.25905
# [117]	validation_0-logloss:0.02204	validation_1-logloss:0.25878
# [118]	validation_0-logloss:0.02176	validation_1-logloss:0.25728
# [119]	validation_0-logloss:0.02149	validation_1-logloss:0.25722
# [120]	validation_0-logloss:0.02119	validation_1-logloss:0.25764
# [121]	validation_0-logloss:0.02095	validation_1-logloss:0.25761
# [122]	validation_0-logloss:0.02067	validation_1-logloss:0.25832
# [123]	validation_0-logloss:0.02045	validation_1-logloss:0.25808
# [124]	validation_0-logloss:0.02023	validation_1-logloss:0.25855
# [125]	validation_0-logloss:0.01998	validation_1-logloss:0.25714
# [126]	validation_0-logloss:0.01973	validation_1-logloss:0.25587
# [127]	validation_0-logloss:0.01946	validation_1-logloss:0.25640
# [128]	validation_0-logloss:0.01927	validation_1-logloss:0.25685
# [129]	validation_0-logloss:0.01908	validation_1-logloss:0.25665
# [130]	validation_0-logloss:0.01886	validation_1-logloss:0.25712
# [131]	validation_0-logloss:0.01863	validation_1-logloss:0.25609
# [132]	validation_0-logloss:0.01839	validation_1-logloss:0.25649
# [133]	validation_0-logloss:0.01816	validation_1-logloss:0.25789
# [134]	validation_0-logloss:0.01802	validation_1-logloss:0.25811
# [135]	validation_0-logloss:0.01785	validation_1-logloss:0.25794
# [136]	validation_0-logloss:0.01763	validation_1-logloss:0.25876
# [137]	validation_0-logloss:0.01748	validation_1-logloss:0.25884
# [138]	validation_0-logloss:0.01732	validation_1-logloss:0.25867
# [139]	validation_0-logloss:0.01719	validation_1-logloss:0.25876
# [140]	validation_0-logloss:0.01696	validation_1-logloss:0.25987
# [141]	validation_0-logloss:0.01681	validation_1-logloss:0.25960
# [142]	validation_0-logloss:0.01669	validation_1-logloss:0.25982
# [143]	validation_0-logloss:0.01656	validation_1-logloss:0.25992
# [144]	validation_0-logloss:0.01638	validation_1-logloss:0.26035
# [145]	validation_0-logloss:0.01623	validation_1-logloss:0.26055
# [146]	validation_0-logloss:0.01606	validation_1-logloss:0.26092
# [147]	validation_0-logloss:0.01589	validation_1-logloss:0.26137
# [148]	validation_0-logloss:0.01572	validation_1-logloss:0.25999
# [149]	validation_0-logloss:0.01557	validation_1-logloss:0.26028
# [150]	validation_0-logloss:0.01546	validation_1-logloss:0.26048
# [151]	validation_0-logloss:0.01531	validation_1-logloss:0.26142
# [152]	validation_0-logloss:0.01515	validation_1-logloss:0.26188
# [153]	validation_0-logloss:0.01501	validation_1-logloss:0.26227
# [154]	validation_0-logloss:0.01486	validation_1-logloss:0.26287
# [155]	validation_0-logloss:0.01476	validation_1-logloss:0.26299
# [156]	validation_0-logloss:0.01461	validation_1-logloss:0.26346
# [157]	validation_0-logloss:0.01448	validation_1-logloss:0.26379
# [158]	validation_0-logloss:0.01434	validation_1-logloss:0.26306
# [159]	validation_0-logloss:0.01424	validation_1-logloss:0.26237
# [160]	validation_0-logloss:0.01410	validation_1-logloss:0.26251
# [161]	validation_0-logloss:0.01401	validation_1-logloss:0.26265
# [162]	validation_0-logloss:0.01392	validation_1-logloss:0.26264
# [163]	validation_0-logloss:0.01380	validation_1-logloss:0.26250
# [164]	validation_0-logloss:0.01372	validation_1-logloss:0.26264
# [165]	validation_0-logloss:0.01359	validation_1-logloss:0.26255
# [166]	validation_0-logloss:0.01350	validation_1-logloss:0.26188
# [167]	validation_0-logloss:0.01342	validation_1-logloss:0.26203
# [168]	validation_0-logloss:0.01331	validation_1-logloss:0.26190
# [169]	validation_0-logloss:0.01319	validation_1-logloss:0.26184
# [170]	validation_0-logloss:0.01312	validation_1-logloss:0.26133
# [171]	validation_0-logloss:0.01304	validation_1-logloss:0.26148
# [172]	validation_0-logloss:0.01297	validation_1-logloss:0.26157
# [173]	validation_0-logloss:0.01285	validation_1-logloss:0.26253
# [174]	validation_0-logloss:0.01278	validation_1-logloss:0.26229
# [175]	validation_0-logloss:0.01267	validation_1-logloss:0.26086
# [176]	validation_0-logloss:0.01258	validation_1-logloss:0.26103

# %%
pip install lightgbm==3.3.2
# Out:
# Collecting lightgbm==3.3.2
#   Downloading lightgbm-3.3.2-py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from lightgbm==3.3.2) (0.43.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightgbm==3.3.2) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm==3.3.2) (1.13.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm==3.3.2) (1.3.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn!=0.22.0->lightgbm==3.3.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn!=0.22.0->lightgbm==3.3.2) (3.5.0)
# Downloading lightgbm-3.3.2-py3-none-manylinux1_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 7.5 MB/s eta 0:00:00
# Installing collected packages: lightgbm
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 4.4.0
#     Uninstalling lightgbm-4.4.0:
#       Successfully uninstalled lightgbm-4.4.0
# Successfully installed lightgbm-3.3.2

# %%
from lightgbm import LGBMClassifier

import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

dataset=load_breast_cancer()

cancer_df=pd.DataFrame(data=dataset.data, columns=dataset.feature_names)
cancer_df['target']=dataset.target
X_features=cancer_df.iloc[:,:-1]
y_label=cancer_df.iloc[:,-1]

X_train, X_test, y_train, y_test=train_test_split(X_features, y_label, test_size=0.2, random_state=156)

X_tr, X_val, y_tr, y_val=train_test_split(X_train, y_train, test_size=0.1, random_state=156)

lgbm_wrapper=LGBMClassifier(n_estimators=400, learning_rate=0.05)

evals=[(X_tr, y_tr),(X_val,y_val)]
lgbm_wrapper.fit(X_tr, y_tr, early_stopping_rounds=50, eval_metric="logloss", eval_set=evals, verbose=True)
preds=lgbm_wrapper.predict(X_test)
pred_proba=lgbm_wrapper.predict_proba(X_test)[:,1]
# Out:
# [1]	training's binary_logloss: 0.625671	valid_1's binary_logloss: 0.628248
# [2]	training's binary_logloss: 0.588173	valid_1's binary_logloss: 0.601106
# [3]	training's binary_logloss: 0.554518	valid_1's binary_logloss: 0.577587
# [4]	training's binary_logloss: 0.523972	valid_1's binary_logloss: 0.556324
# [5]	training's binary_logloss: 0.49615	valid_1's binary_logloss: 0.537407
# [6]	training's binary_logloss: 0.470108	valid_1's binary_logloss: 0.519401
# [7]	training's binary_logloss: 0.446647	valid_1's binary_logloss: 0.502637
# [8]	training's binary_logloss: 0.425055	valid_1's binary_logloss: 0.488311
# [9]	training's binary_logloss: 0.405125	valid_1's binary_logloss: 0.474664
# [10]	training's binary_logloss: 0.386526	valid_1's binary_logloss: 0.461267
# [11]	training's binary_logloss: 0.367027	valid_1's binary_logloss: 0.444274
# [12]	training's binary_logloss: 0.350713	valid_1's binary_logloss: 0.432755
# [13]	training's binary_logloss: 0.334601	valid_1's binary_logloss: 0.421371
# [14]	training's binary_logloss: 0.319854	valid_1's binary_logloss: 0.411418
# [15]	training's binary_logloss: 0.306374	valid_1's binary_logloss: 0.402989
# [16]	training's binary_logloss: 0.293116	valid_1's binary_logloss: 0.393973
# [17]	training's binary_logloss: 0.280812	valid_1's binary_logloss: 0.384801
# [18]	training's binary_logloss: 0.268352	valid_1's binary_logloss: 0.376191
# [19]	training's binary_logloss: 0.256942	valid_1's binary_logloss: 0.368378
# [20]	training's binary_logloss: 0.246443	valid_1's binary_logloss: 0.362062
# [21]	training's binary_logloss: 0.236874	valid_1's binary_logloss: 0.355162
# [22]	training's binary_logloss: 0.227501	valid_1's binary_logloss: 0.348933
# [23]	training's binary_logloss: 0.218988	valid_1's binary_logloss: 0.342819
# [24]	training's binary_logloss: 0.210621	valid_1's binary_logloss: 0.337386
# [25]	training's binary_logloss: 0.202076	valid_1's binary_logloss: 0.331523
# [26]	training's binary_logloss: 0.194199	valid_1's binary_logloss: 0.326349
# [27]	training's binary_logloss: 0.187107	valid_1's binary_logloss: 0.322785
# [28]	training's binary_logloss: 0.180535	valid_1's binary_logloss: 0.317877
# [29]	training's binary_logloss: 0.173834	valid_1's binary_logloss: 0.313928
# [30]	training's binary_logloss: 0.167198	valid_1's binary_logloss: 0.310105
# [31]	training's binary_logloss: 0.161229	valid_1's binary_logloss: 0.307107
# [32]	training's binary_logloss: 0.155494	valid_1's binary_logloss: 0.303837
# [33]	training's binary_logloss: 0.149125	valid_1's binary_logloss: 0.300315
# [34]	training's binary_logloss: 0.144045	valid_1's binary_logloss: 0.297816
# [35]	training's binary_logloss: 0.139341	valid_1's binary_logloss: 0.295387
# [36]	training's binary_logloss: 0.134625	valid_1's binary_logloss: 0.293063
# [37]	training's binary_logloss: 0.129167	valid_1's binary_logloss: 0.289127
# [38]	training's binary_logloss: 0.12472	valid_1's binary_logloss: 0.288697
# [39]	training's binary_logloss: 0.11974	valid_1's binary_logloss: 0.28576
# [40]	training's binary_logloss: 0.115054	valid_1's binary_logloss: 0.282853
# [41]	training's binary_logloss: 0.110662	valid_1's binary_logloss: 0.279441
# [42]	training's binary_logloss: 0.106358	valid_1's binary_logloss: 0.28113
# [43]	training's binary_logloss: 0.102324	valid_1's binary_logloss: 0.279139
# [44]	training's binary_logloss: 0.0985699	valid_1's binary_logloss: 0.276465
# [45]	training's binary_logloss: 0.094858	valid_1's binary_logloss: 0.275946
# [46]	training's binary_logloss: 0.0912486	valid_1's binary_logloss: 0.272819
# [47]	training's binary_logloss: 0.0883115	valid_1's binary_logloss: 0.272306
# [48]	training's binary_logloss: 0.0849963	valid_1's binary_logloss: 0.270452
# [49]	training's binary_logloss: 0.0821742	valid_1's binary_logloss: 0.268671
# [50]	training's binary_logloss: 0.0789991	valid_1's binary_logloss: 0.267587
# [51]	training's binary_logloss: 0.0761072	valid_1's binary_logloss: 0.26626
# [52]	training's binary_logloss: 0.0732567	valid_1's binary_logloss: 0.265542
# [53]	training's binary_logloss: 0.0706388	valid_1's binary_logloss: 0.264547
# [54]	training's binary_logloss: 0.0683911	valid_1's binary_logloss: 0.26502
# [55]	training's binary_logloss: 0.0659347	valid_1's binary_logloss: 0.264388
# [56]	training's binary_logloss: 0.0636873	valid_1's binary_logloss: 0.263128
# [57]	training's binary_logloss: 0.0613354	valid_1's binary_logloss: 0.26231
# [58]	training's binary_logloss: 0.0591944	valid_1's binary_logloss: 0.262011
# [59]	training's binary_logloss: 0.057033	valid_1's binary_logloss: 0.261454
# [60]	training's binary_logloss: 0.0550801	valid_1's binary_logloss: 0.260746
# [61]	training's binary_logloss: 0.0532381	valid_1's binary_logloss: 0.260236
# [62]	training's binary_logloss: 0.0514074	valid_1's binary_logloss: 0.261586
# [63]	training's binary_logloss: 0.0494837	valid_1's binary_logloss: 0.261797
# [64]	training's binary_logloss: 0.0477826	valid_1's binary_logloss: 0.262533
# [65]	training's binary_logloss: 0.0460364	valid_1's binary_logloss: 0.263305
# [66]	training's binary_logloss: 0.0444552	valid_1's binary_logloss: 0.264072
# [67]	training's binary_logloss: 0.0427638	valid_1's binary_logloss: 0.266223
# [68]	training's binary_logloss: 0.0412449	valid_1's binary_logloss: 0.266817
# [69]	training's binary_logloss: 0.0398589	valid_1's binary_logloss: 0.267819
# [70]	training's binary_logloss: 0.0383095	valid_1's binary_logloss: 0.267484
# [71]	training's binary_logloss: 0.0368803	valid_1's binary_logloss: 0.270233
# [72]	training's binary_logloss: 0.0355637	valid_1's binary_logloss: 0.268442
# [73]	training's binary_logloss: 0.0341747	valid_1's binary_logloss: 0.26895
# [74]	training's binary_logloss: 0.0328302	valid_1's binary_logloss: 0.266958
# [75]	training's binary_logloss: 0.0317853	valid_1's binary_logloss: 0.268091
# [76]	training's binary_logloss: 0.0305626	valid_1's binary_logloss: 0.266419
# [77]	training's binary_logloss: 0.0295001	valid_1's binary_logloss: 0.268588
# [78]	training's binary_logloss: 0.0284699	valid_1's binary_logloss: 0.270964
# [79]	training's binary_logloss: 0.0273953	valid_1's binary_logloss: 0.270293
# [80]	training's binary_logloss: 0.0264668	valid_1's binary_logloss: 0.270523
# [81]	training's binary_logloss: 0.0254636	valid_1's binary_logloss: 0.270683
# [82]	training's binary_logloss: 0.0245911	valid_1's binary_logloss: 0.273187
# [83]	training's binary_logloss: 0.0236486	valid_1's binary_logloss: 0.275994
# [84]	training's binary_logloss: 0.0228047	valid_1's binary_logloss: 0.274053
# [85]	training's binary_logloss: 0.0221693	valid_1's binary_logloss: 0.273211
# [86]	training's binary_logloss: 0.0213043	valid_1's binary_logloss: 0.272626
# [87]	training's binary_logloss: 0.0203934	valid_1's binary_logloss: 0.27534
# [88]	training's binary_logloss: 0.0195552	valid_1's binary_logloss: 0.276228
# [89]	training's binary_logloss: 0.0188623	valid_1's binary_logloss: 0.27525
# [90]	training's binary_logloss: 0.0183664	valid_1's binary_logloss: 0.276485
# [91]	training's binary_logloss: 0.0176788	valid_1's binary_logloss: 0.277052
# [92]	training's binary_logloss: 0.0170059	valid_1's binary_logloss: 0.277686
# [93]	training's binary_logloss: 0.0164317	valid_1's binary_logloss: 0.275332
# [94]	training's binary_logloss: 0.015878	valid_1's binary_logloss: 0.276236
# [95]	training's binary_logloss: 0.0152959	valid_1's binary_logloss: 0.274538
# [96]	training's binary_logloss: 0.0147216	valid_1's binary_logloss: 0.275244
# [97]	training's binary_logloss: 0.0141758	valid_1's binary_logloss: 0.275829
# [98]	training's binary_logloss: 0.0136551	valid_1's binary_logloss: 0.276654
# [99]	training's binary_logloss: 0.0131585	valid_1's binary_logloss: 0.277859
# [100]	training's binary_logloss: 0.0126961	valid_1's binary_logloss: 0.279265
# [101]	training's binary_logloss: 0.0122421	valid_1's binary_logloss: 0.276695
# [102]	training's binary_logloss: 0.0118067	valid_1's binary_logloss: 0.278488
# [103]	training's binary_logloss: 0.0113994	valid_1's binary_logloss: 0.278932
# [104]	training's binary_logloss: 0.0109799	valid_1's binary_logloss: 0.280997
# [105]	training's binary_logloss: 0.0105953	valid_1's binary_logloss: 0.281454
# [106]	training's binary_logloss: 0.0102381	valid_1's binary_logloss: 0.282058
# [107]	training's binary_logloss: 0.00986714	valid_1's binary_logloss: 0.279275
# [108]	training's binary_logloss: 0.00950998	valid_1's binary_logloss: 0.281427
# [109]	training's binary_logloss: 0.00915965	valid_1's binary_logloss: 0.280752
# [110]	training's binary_logloss: 0.00882581	valid_1's binary_logloss: 0.282152
# [111]	training's binary_logloss: 0.00850714	valid_1's binary_logloss: 0.280894

# %%
pip install hyperopt
# Out:
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.10/dist-packages (0.2.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from hyperopt) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from hyperopt) (1.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from hyperopt) (1.16.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from hyperopt) (3.3)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from hyperopt) (1.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from hyperopt) (4.66.4)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from hyperopt) (2.2.1)
# Requirement already satisfied: py4j in /usr/local/lib/python3.10/dist-packages (from hyperopt) (0.10.9.7)

# %%
from hyperopt import hp

search_space={'x': hp.quniform('x',-10,10,1), 'y':hp.quniform('y',-15,15,1)}

# %%
def objective_func(search_space):
  x=search_space['x']
  y=search_space['y']
  retval=x**2-20*y
  return retval

# %%
from hyperopt import fmin,tpe,Trials
trial_val=Trials()
best_01=fmin(fn=objective_func, space=search_space, algo=tpe.suggest, max_evals=5, trials=trial_val, rstate=np.random.default_rng(seed=0))
print('best:', best_01)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 257.40trial/s, best loss: -224.0]
# best: {'x': -4.0, 'y': 12.0}

# %%
trial_val=Trials()

best_02=fmin(fn=objective_func, space=search_space, algo=tpe.suggest, max_evals=20, trials=trial_val, rstate=np.random.default_rng(seed=0))
print('best:',best_02)
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 445.26trial/s, best loss: -296.0]
# best: {'x': 2.0, 'y': 15.0}

# %%
print(trial_val.results)
# Out:
# [{'loss': -64.0, 'status': 'ok'}, {'loss': -184.0, 'status': 'ok'}, {'loss': 56.0, 'status': 'ok'}, {'loss': -224.0, 'status': 'ok'}, {'loss': 61.0, 'status': 'ok'}, {'loss': -296.0, 'status': 'ok'}, {'loss': -40.0, 'status': 'ok'}, {'loss': 281.0, 'status': 'ok'}, {'loss': 64.0, 'status': 'ok'}, {'loss': 100.0, 'status': 'ok'}, {'loss': 60.0, 'status': 'ok'}, {'loss': -39.0, 'status': 'ok'}, {'loss': 1.0, 'status': 'ok'}, {'loss': -164.0, 'status': 'ok'}, {'loss': 21.0, 'status': 'ok'}, {'loss': -56.0, 'status': 'ok'}, {'loss': 284.0, 'status': 'ok'}, {'loss': 176.0, 'status': 'ok'}, {'loss': -171.0, 'status': 'ok'}, {'loss': 0.0, 'status': 'ok'}]

# %%
losses=[loss_dict['loss'] for loss_dict in trial_val.results]

result_df=pd.DataFrame({'x':trial_val.vals['x'], 'y':trial_val.vals['y'],'losses':losses})
result_df
# Out:
#        x     y  losses
# 0   -6.0   5.0   -64.0
# 1   -4.0  10.0  -184.0
# 2    4.0  -2.0    56.0
# 3   -4.0  12.0  -224.0
# 4    9.0   1.0    61.0
# 5    2.0  15.0  -296.0
# 6   10.0   7.0   -40.0
# 7   -9.0 -10.0   281.0
# 8   -8.0   0.0    64.0
# 9   -0.0  -5.0   100.0
# 10  -0.0  -3.0    60.0
# 11   1.0   2.0   -39.0
# 12   9.0   4.0     1.0
# 13   6.0  10.0  -164.0
# 14   9.0   3.0    21.0
# 15   2.0   3.0   -56.0
# 16  -2.0 -14.0   284.0
# 17  -4.0  -8.0   176.0
# 18   7.0  11.0  -171.0
# 19  -0.0  -0.0     0.0

# %%
xgb_search_space={'max_depth':hp.quniform('max_depth',5,20,1),
                  'min_child_weight': hp.quniform('min_child_weight',1,2,2),
                  'learning_rate': hp.uniform('learning_rate',0.01,0.2),
                  'colsample_bytree':hp.uniform('colsample_bytree',0.5,1),
                  }

# %%
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier
from hyperopt import STATUS_OK

def objective_func(search_space):
  xgb_clf=XGBClassifier(n_estimators=100, max_depth=int(search_space['max_depth']),
                        min_child_weight=int(search_space['min_child_weight']),
                        learning_rate=search_space['learning_rate'],
                        colsample_bytree=search_space['colsample_bytree'],
                        eval_metric='logloss')
  accuracy=cross_val_score(xgb_clf, X_train, y_train, scoring='accuracy', cv=3)

  return {'loss':-1*np.mean(accuracy), 'status':STATUS_OK}

# %%
from hyperopt import fmin,tpe,Trials

trial_val=Trials()
best=fmin(fn=objective_func,
         space=xgb_search_space,
         algo=tpe.suggest,
         max_evals=50,
         trials=trial_val, rstate=np.random.default_rng(seed=9)
         )
print('best:',best)
# Out:
# 100%|██████████| 50/50 [07:01<00:00,  8.44s/trial, best loss: -0.9692401533635412]
# best: {'colsample_bytree': 0.6100822226603742, 'learning_rate': 0.19898384214502335, 'max_depth': 10.0, 'min_child_weight': 2.0}

# %%
print('colsample_bytree:{0}, learning_rate:{1},max_depth:{2},min_child_weight:{3}'.format(round(best['colsample_bytree'],5),round(best['learning_rate'],5), int(best['max_depth']),int(best['min_child_weight'])))
# Out:
# colsample_bytree:0.61008, learning_rate:0.19898,max_depth:10,min_child_weight:2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import warnings

warnings.filterwarnings('ignore')
cust_df=pd.read_csv('train_santander.csv',encoding='latin-1')
print('dataset shape:', cust_df.shape)
cust_df.head(3)
# Out:
# dataset shape: (76020, 371)
#    ID  var3  var15  ...  saldo_medio_var44_ult3     var38  TARGET
# 0   1     2     23  ...                     0.0  39205.17       0
# 1   3     2     34  ...                     0.0  49278.03       0
# 2   4     2     23  ...                     0.0  67333.77       0
#
# [3 rows x 371 columns]

# %%
print(cust_df['TARGET'].value_counts())
unsatisfied_cnt=cust_df[cust_df['TARGET']==1].TARGET.count()
total_cnt=cust_df.TARGET.count()
print('unsatisfied 비율은 {0:.2f}'.format((unsatisfied_cnt/total_cnt)))
# Out:
# 0    73012
# 1     3008
# Name: TARGET, dtype: int64
# unsatisfied 비율은 0.04

# %%
cust_df.describe()
# Out:
#                   ID           var3  ...         var38        TARGET
# count   76020.000000   76020.000000  ...  7.602000e+04  76020.000000
# mean    75964.050723   -1523.199277  ...  1.172358e+05      0.039569
# std     43781.947379   39033.462364  ...  1.826646e+05      0.194945
# min         1.000000 -999999.000000  ...  5.163750e+03      0.000000
# 25%     38104.750000       2.000000  ...  6.787061e+04      0.000000
# 50%     76043.000000       2.000000  ...  1.064092e+05      0.000000
# 75%    113748.750000       2.000000  ...  1.187563e+05      0.000000
# max    151838.000000     238.000000  ...  2.203474e+07      1.000000
#
# [8 rows x 371 columns]

# %%
cust_df['var3'].replace(-999999,2,inplace=True)
cust_df.drop('ID',axis=1,inplace=True)

X_features=cust_df.iloc[:,:-1]
y_labels=cust_df.iloc[:,-1]

print('피처 데이터 shape:{0}'.format(X_features.shape))
# Out:
# 피처 데이터 shape:(76020, 369)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X_features,y_labels,
                                               test_size=0.2, random_state=0)
train_cnt=y_train.count()
test_cnt=y_test.count()
print('학습 세트 Shape:{0}, 테스트 세트 Shape:{1}'.format(X_train.shape, X_test.shape))

print('학습 세트 레이블 값 분포 비율')
print(y_train.value_counts()/train_cnt)
print('\n테스트 세트 레이블 값 분포 비율')
print(y_test.value_counts()/test_cnt)
# Out:
# 학습 세트 Shape:(60816, 369), 테스트 세트 Shape:(15204, 369)
# 학습 세트 레이블 값 분포 비율
# 0    0.960964
# 1    0.039036
# Name: TARGET, dtype: float64
#
# 테스트 세트 레이블 값 분포 비율
# 0    0.9583
# 1    0.0417
# Name: TARGET, dtype: float64

# %%
X_tr, X_val, y_tr, y_val=train_test_split(X_train, y_train, test_size=0.3, random_state=0)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score

xgb_clf=XGBClassifier(n_estimators=500, learning_rate=0.05, random_state=156)

xgb_clf.fit(X_tr, y_tr, early_stopping_rounds=100, eval_metric="auc",
            eval_set=[(X_tr,y_tr),(X_val,y_val)])

xgb_roc_score=roc_auc_score(y_test, xgb_clf.predict_proba(X_test)[:,1])
print('ROC AUC: {0:4f}'.format(xgb_roc_score))
# Out:
# [0]	validation_0-auc:0.82179	validation_1-auc:0.80068
# [1]	validation_0-auc:0.83092	validation_1-auc:0.80941
# [2]	validation_0-auc:0.83207	validation_1-auc:0.80903
# [3]	validation_0-auc:0.83288	validation_1-auc:0.80889
# [4]	validation_0-auc:0.83414	validation_1-auc:0.80924
# [5]	validation_0-auc:0.83524	validation_1-auc:0.80907
# [6]	validation_0-auc:0.83568	validation_1-auc:0.81005
# [7]	validation_0-auc:0.83741	validation_1-auc:0.81088
# [8]	validation_0-auc:0.83896	validation_1-auc:0.81305
# [9]	validation_0-auc:0.83949	validation_1-auc:0.81363
# [10]	validation_0-auc:0.83908	validation_1-auc:0.81277
# [11]	validation_0-auc:0.83913	validation_1-auc:0.81260
# [12]	validation_0-auc:0.84009	validation_1-auc:0.81325
# [13]	validation_0-auc:0.84081	validation_1-auc:0.81329
# [14]	validation_0-auc:0.84196	validation_1-auc:0.81380
# [15]	validation_0-auc:0.84394	validation_1-auc:0.81540
# [16]	validation_0-auc:0.84414	validation_1-auc:0.81573
# [17]	validation_0-auc:0.84437	validation_1-auc:0.81577
# [18]	validation_0-auc:0.84468	validation_1-auc:0.81569
# [19]	validation_0-auc:0.84586	validation_1-auc:0.81625
# [20]	validation_0-auc:0.84641	validation_1-auc:0.81619
# [21]	validation_0-auc:0.84685	validation_1-auc:0.81611
# [22]	validation_0-auc:0.84735	validation_1-auc:0.81671
# [23]	validation_0-auc:0.84793	validation_1-auc:0.81682
# [24]	validation_0-auc:0.84825	validation_1-auc:0.81675
# [25]	validation_0-auc:0.84893	validation_1-auc:0.81647
# [26]	validation_0-auc:0.85104	validation_1-auc:0.81724
# [27]	validation_0-auc:0.85206	validation_1-auc:0.81764
# [28]	validation_0-auc:0.85327	validation_1-auc:0.81873
# [29]	validation_0-auc:0.85425	validation_1-auc:0.82038
# [30]	validation_0-auc:0.85624	validation_1-auc:0.82231
# [31]	validation_0-auc:0.85716	validation_1-auc:0.82223
# [32]	validation_0-auc:0.85785	validation_1-auc:0.82261
# [33]	validation_0-auc:0.85878	validation_1-auc:0.82289
# [34]	validation_0-auc:0.85931	validation_1-auc:0.82389
# [35]	validation_0-auc:0.86006	validation_1-auc:0.82446
# [36]	validation_0-auc:0.86079	validation_1-auc:0.82537
# [37]	validation_0-auc:0.86101	validation_1-auc:0.82546
# [38]	validation_0-auc:0.86156	validation_1-auc:0.82593
# [39]	validation_0-auc:0.86224	validation_1-auc:0.82610
# [40]	validation_0-auc:0.86284	validation_1-auc:0.82603
# [41]	validation_0-auc:0.86314	validation_1-auc:0.82624
# [42]	validation_0-auc:0.86388	validation_1-auc:0.82694
# [43]	validation_0-auc:0.86493	validation_1-auc:0.82741
# [44]	validation_0-auc:0.86557	validation_1-auc:0.82757
# [45]	validation_0-auc:0.86643	validation_1-auc:0.82795
# [46]	validation_0-auc:0.86733	validation_1-auc:0.82860
# [47]	validation_0-auc:0.86788	validation_1-auc:0.82878
# [48]	validation_0-auc:0.86815	validation_1-auc:0.82881
# [49]	validation_0-auc:0.86902	validation_1-auc:0.83000
# [50]	validation_0-auc:0.86956	validation_1-auc:0.83040
# [51]	validation_0-auc:0.86992	validation_1-auc:0.83036
# [52]	validation_0-auc:0.87037	validation_1-auc:0.83061
# [53]	validation_0-auc:0.87088	validation_1-auc:0.83071
# [54]	validation_0-auc:0.87157	validation_1-auc:0.83092
# [55]	validation_0-auc:0.87206	validation_1-auc:0.83143
# [56]	validation_0-auc:0.87277	validation_1-auc:0.83170
# [57]	validation_0-auc:0.87329	validation_1-auc:0.83171
# [58]	validation_0-auc:0.87369	validation_1-auc:0.83168
# [59]	validation_0-auc:0.87428	validation_1-auc:0.83172
# [60]	validation_0-auc:0.87489	validation_1-auc:0.83166
# [61]	validation_0-auc:0.87565	validation_1-auc:0.83160
# [62]	validation_0-auc:0.87618	validation_1-auc:0.83164
# [63]	validation_0-auc:0.87685	validation_1-auc:0.83174
# [64]	validation_0-auc:0.87749	validation_1-auc:0.83209
# [65]	validation_0-auc:0.87810	validation_1-auc:0.83233
# [66]	validation_0-auc:0.87867	validation_1-auc:0.83246
# [67]	validation_0-auc:0.87932	validation_1-auc:0.83256
# [68]	validation_0-auc:0.87982	validation_1-auc:0.83264
# [69]	validation_0-auc:0.88036	validation_1-auc:0.83250
# [70]	validation_0-auc:0.88087	validation_1-auc:0.83226
# [71]	validation_0-auc:0.88182	validation_1-auc:0.83208
# [72]	validation_0-auc:0.88232	validation_1-auc:0.83234
# [73]	validation_0-auc:0.88293	validation_1-auc:0.83247
# [74]	validation_0-auc:0.88342	validation_1-auc:0.83244
# [75]	validation_0-auc:0.88401	validation_1-auc:0.83246
# [76]	validation_0-auc:0.88451	validation_1-auc:0.83238
# [77]	validation_0-auc:0.88487	validation_1-auc:0.83224
# [78]	validation_0-auc:0.88518	validation_1-auc:0.83234
# [79]	validation_0-auc:0.88561	validation_1-auc:0.83233
# [80]	validation_0-auc:0.88637	validation_1-auc:0.83253
# [81]	validation_0-auc:0.88665	validation_1-auc:0.83255
# [82]	validation_0-auc:0.88703	validation_1-auc:0.83245
# [83]	validation_0-auc:0.88756	validation_1-auc:0.83261
# [84]	validation_0-auc:0.88791	validation_1-auc:0.83249
# [85]	validation_0-auc:0.88852	validation_1-auc:0.83263
# [86]	validation_0-auc:0.88895	validation_1-auc:0.83251
# [87]	validation_0-auc:0.88933	validation_1-auc:0.83237
# [88]	validation_0-auc:0.88970	validation_1-auc:0.83233
# [89]	validation_0-auc:0.89021	validation_1-auc:0.83231
# [90]	validation_0-auc:0.89065	validation_1-auc:0.83222
# [91]	validation_0-auc:0.89105	validation_1-auc:0.83236
# [92]	validation_0-auc:0.89142	validation_1-auc:0.83218
# [93]	validation_0-auc:0.89176	validation_1-auc:0.83239
# [94]	validation_0-auc:0.89213	validation_1-auc:0.83220
# [95]	validation_0-auc:0.89241	validation_1-auc:0.83227
# [96]	validation_0-auc:0.89278	validation_1-auc:0.83213
# [97]	validation_0-auc:0.89302	validation_1-auc:0.83223
# [98]	validation_0-auc:0.89329	validation_1-auc:0.83209
# [99]	validation_0-auc:0.89361	validation_1-auc:0.83227
# [100]	validation_0-auc:0.89380	validation_1-auc:0.83236
# [101]	validation_0-auc:0.89410	validation_1-auc:0.83232
# [102]	validation_0-auc:0.89438	validation_1-auc:0.83227
# [103]	validation_0-auc:0.89474	validation_1-auc:0.83220
# [104]	validation_0-auc:0.89509	validation_1-auc:0.83221
# [105]	validation_0-auc:0.89550	validation_1-auc:0.83226
# [106]	validation_0-auc:0.89586	validation_1-auc:0.83224
# [107]	validation_0-auc:0.89604	validation_1-auc:0.83231
# [108]	validation_0-auc:0.89611	validation_1-auc:0.83229
# [109]	validation_0-auc:0.89634	validation_1-auc:0.83230
# [110]	validation_0-auc:0.89666	validation_1-auc:0.83242
# [111]	validation_0-auc:0.89677	validation_1-auc:0.83238
# [112]	validation_0-auc:0.89695	validation_1-auc:0.83241
# [113]	validation_0-auc:0.89720	validation_1-auc:0.83241
# [114]	validation_0-auc:0.89728	validation_1-auc:0.83247
# [115]	validation_0-auc:0.89739	validation_1-auc:0.83249
# [116]	validation_0-auc:0.89764	validation_1-auc:0.83240
# [117]	validation_0-auc:0.89780	validation_1-auc:0.83240
# [118]	validation_0-auc:0.89793	validation_1-auc:0.83257
# [119]	validation_0-auc:0.89851	validation_1-auc:0.83260
# [120]	validation_0-auc:0.89886	validation_1-auc:0.83279
# [121]	validation_0-auc:0.89929	validation_1-auc:0.83272
# [122]	validation_0-auc:0.89957	validation_1-auc:0.83273
# [123]	validation_0-auc:0.90005	validation_1-auc:0.83269
# [124]	validation_0-auc:0.90036	validation_1-auc:0.83284
# [125]	validation_0-auc:0.90077	validation_1-auc:0.83297
# [126]	validation_0-auc:0.90086	validation_1-auc:0.83300
# [127]	validation_0-auc:0.90114	validation_1-auc:0.83315
# [128]	validation_0-auc:0.90151	validation_1-auc:0.83316
# [129]	validation_0-auc:0.90181	validation_1-auc:0.83337
# [130]	validation_0-auc:0.90211	validation_1-auc:0.83340
# [131]	validation_0-auc:0.90240	validation_1-auc:0.83340
# [132]	validation_0-auc:0.90266	validation_1-auc:0.83353
# [133]	validation_0-auc:0.90277	validation_1-auc:0.83347
# [134]	validation_0-auc:0.90279	validation_1-auc:0.83353
# [135]	validation_0-auc:0.90292	validation_1-auc:0.83353
# [136]	validation_0-auc:0.90302	validation_1-auc:0.83344
# [137]	validation_0-auc:0.90309	validation_1-auc:0.83348
# [138]	validation_0-auc:0.90312	validation_1-auc:0.83344
# [139]	validation_0-auc:0.90325	validation_1-auc:0.83340
# [140]	validation_0-auc:0.90338	validation_1-auc:0.83335
# [141]	validation_0-auc:0.90339	validation_1-auc:0.83339
# [142]	validation_0-auc:0.90363	validation_1-auc:0.83351
# [143]	validation_0-auc:0.90383	validation_1-auc:0.83358
# [144]	validation_0-auc:0.90395	validation_1-auc:0.83357
# [145]	validation_0-auc:0.90399	validation_1-auc:0.83361
# [146]	validation_0-auc:0.90417	validation_1-auc:0.83354
# [147]	validation_0-auc:0.90430	validation_1-auc:0.83349
# [148]	validation_0-auc:0.90434	validation_1-auc:0.83346
# [149]	validation_0-auc:0.90451	validation_1-auc:0.83346
# [150]	validation_0-auc:0.90459	validation_1-auc:0.83343
# [151]	validation_0-auc:0.90462	validation_1-auc:0.83344
# [152]	validation_0-auc:0.90476	validation_1-auc:0.83342
# [153]	validation_0-auc:0.90494	validation_1-auc:0.83339
# [154]	validation_0-auc:0.90507	validation_1-auc:0.83336
# [155]	validation_0-auc:0.90512	validation_1-auc:0.83334
# [156]	validation_0-auc:0.90518	validation_1-auc:0.83331
# [157]	validation_0-auc:0.90524	validation_1-auc:0.83339
# [158]	validation_0-auc:0.90543	validation_1-auc:0.83330
# [159]	validation_0-auc:0.90553	validation_1-auc:0.83331
# [160]	validation_0-auc:0.90567	validation_1-auc:0.83342
# [161]	validation_0-auc:0.90586	validation_1-auc:0.83339
# [162]	validation_0-auc:0.90592	validation_1-auc:0.83340
# [163]	validation_0-auc:0.90594	validation_1-auc:0.83340
# [164]	validation_0-auc:0.90622	validation_1-auc:0.83337
# [165]	validation_0-auc:0.90634	validation_1-auc:0.83333
# [166]	validation_0-auc:0.90645	validation_1-auc:0.83329
# [167]	validation_0-auc:0.90654	validation_1-auc:0.83329
# [168]	validation_0-auc:0.90659	validation_1-auc:0.83336
# [169]	validation_0-auc:0.90670	validation_1-auc:0.83339
# [170]	validation_0-auc:0.90675	validation_1-auc:0.83341
# [171]	validation_0-auc:0.90679	validation_1-auc:0.83334
# [172]	validation_0-auc:0.90701	validation_1-auc:0.83321
# [173]	validation_0-auc:0.90702	validation_1-auc:0.83321
# [174]	validation_0-auc:0.90706	validation_1-auc:0.83319
# [175]	validation_0-auc:0.90720	validation_1-auc:0.83323
# [176]	validation_0-auc:0.90730	validation_1-auc:0.83325
# [177]	validation_0-auc:0.90741	validation_1-auc:0.83323
# [178]	validation_0-auc:0.90753	validation_1-auc:0.83318
# [179]	validation_0-auc:0.90761	validation_1-auc:0.83317
# [180]	validation_0-auc:0.90768	validation_1-auc:0.83315
# [181]	validation_0-auc:0.90773	validation_1-auc:0.83313
# [182]	validation_0-auc:0.90785	validation_1-auc:0.83312
# [183]	validation_0-auc:0.90804	validation_1-auc:0.83303
# [184]	validation_0-auc:0.90816	validation_1-auc:0.83305
# [185]	validation_0-auc:0.90821	validation_1-auc:0.83307
# [186]	validation_0-auc:0.90823	validation_1-auc:0.83307
# [187]	validation_0-auc:0.90836	validation_1-auc:0.83308
# [188]	validation_0-auc:0.90841	validation_1-auc:0.83309
# [189]	validation_0-auc:0.90882	validation_1-auc:0.83304
# [190]	validation_0-auc:0.90885	validation_1-auc:0.83306
# [191]	validation_0-auc:0.90897	validation_1-auc:0.83301
# [192]	validation_0-auc:0.90909	validation_1-auc:0.83302
# [193]	validation_0-auc:0.90914	validation_1-auc:0.83303
# [194]	validation_0-auc:0.90927	validation_1-auc:0.83300
# [195]	validation_0-auc:0.90946	validation_1-auc:0.83298
# [196]	validation_0-auc:0.90959	validation_1-auc:0.83291
# [197]	validation_0-auc:0.90970	validation_1-auc:0.83293
# [198]	validation_0-auc:0.90972	validation_1-auc:0.83293
# [199]	validation_0-auc:0.90986	validation_1-auc:0.83293
# [200]	validation_0-auc:0.90992	validation_1-auc:0.83293
# [201]	validation_0-auc:0.90997	validation_1-auc:0.83291
# [202]	validation_0-auc:0.91010	validation_1-auc:0.83290
# [203]	validation_0-auc:0.91016	validation_1-auc:0.83287
# [204]	validation_0-auc:0.91025	validation_1-auc:0.83289
# [205]	validation_0-auc:0.91045	validation_1-auc:0.83282
# [206]	validation_0-auc:0.91056	validation_1-auc:0.83280
# [207]	validation_0-auc:0.91060	validation_1-auc:0.83287
# [208]	validation_0-auc:0.91063	validation_1-auc:0.83291
# [209]	validation_0-auc:0.91068	validation_1-auc:0.83292
# [210]	validation_0-auc:0.91069	validation_1-auc:0.83290
# [211]	validation_0-auc:0.91077	validation_1-auc:0.83286
# [212]	validation_0-auc:0.91084	validation_1-auc:0.83286
# [213]	validation_0-auc:0.91099	validation_1-auc:0.83293
# [214]	validation_0-auc:0.91133	validation_1-auc:0.83279
# [215]	validation_0-auc:0.91137	validation_1-auc:0.83276
# [216]	validation_0-auc:0.91143	validation_1-auc:0.83274
# [217]	validation_0-auc:0.91150	validation_1-auc:0.83274
# [218]	validation_0-auc:0.91158	validation_1-auc:0.83268
# [219]	validation_0-auc:0.91163	validation_1-auc:0.83267
# [220]	validation_0-auc:0.91165	validation_1-auc:0.83267
# [221]	validation_0-auc:0.91175	validation_1-auc:0.83269
# [222]	validation_0-auc:0.91192	validation_1-auc:0.83259
# [223]	validation_0-auc:0.91194	validation_1-auc:0.83260
# [224]	validation_0-auc:0.91199	validation_1-auc:0.83258
# [225]	validation_0-auc:0.91206	validation_1-auc:0.83262
# [226]	validation_0-auc:0.91210	validation_1-auc:0.83262
# [227]	validation_0-auc:0.91215	validation_1-auc:0.83263
# [228]	validation_0-auc:0.91231	validation_1-auc:0.83247
# [229]	validation_0-auc:0.91255	validation_1-auc:0.83239
# [230]	validation_0-auc:0.91281	validation_1-auc:0.83225
# [231]	validation_0-auc:0.91286	validation_1-auc:0.83222
# [232]	validation_0-auc:0.91294	validation_1-auc:0.83224
# [233]	validation_0-auc:0.91299	validation_1-auc:0.83227
# [234]	validation_0-auc:0.91317	validation_1-auc:0.83221
# [235]	validation_0-auc:0.91323	validation_1-auc:0.83221
# [236]	validation_0-auc:0.91349	validation_1-auc:0.83213
# [237]	validation_0-auc:0.91351	validation_1-auc:0.83208
# [238]	validation_0-auc:0.91362	validation_1-auc:0.83204
# [239]	validation_0-auc:0.91365	validation_1-auc:0.83201
# [240]	validation_0-auc:0.91370	validation_1-auc:0.83198
# [241]	validation_0-auc:0.91380	validation_1-auc:0.83197
# [242]	validation_0-auc:0.91385	validation_1-auc:0.83197
# [243]	validation_0-auc:0.91387	validation_1-auc:0.83197
# [244]	validation_0-auc:0.91395	validation_1-auc:0.83204
# ROC AUC: 0.842853

# %%
from hyperopt import hp

xbg_search_space={'max_depth':hp.quniform('max_depth',5,15,1),
                  'min_child_weight':hp.quniform('min_child_weight',1,6,1),
                  'colsample_bytree':hp.uniform('colsample_bytree',0.5,0.95),
                  'learning_rate':hp.uniform('learning_rate',0.01,0.2)}

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score

def objective_func(search_space):
  xgb_clf=XGBClassifier(n_estimators=100, max_depth=int(search_space['max_depth']),
                        min_child_weight=int(search_space['min_child_weight']),
                        colsample_bytree=search_space['colsample_bytree'],
                        learning_rate=search_space['learning_rate'])

  roc_auc_list=[]

  kf=KFold(n_splits=3)

  for tr_index, val_index in kf.split(X_train):
    X_tr, y_tr=X_train.iloc[tr_index],y_train.iloc[tr_index]
    X_val, y_val=X_train.iloc[val_index],y_train.iloc[val_index]

    xgb_clf.fit(X_tr, y_tr, early_stopping_rounds=30, eval_metric="auc",
                eval_set=[(X_tr,y_tr),(X_val,y_val)])

    score=roc_auc_score(y_val, xgb_clf.predict_proba(X_val)[:,1])
    roc_auc_list.append(score)

  return -1*np.mean(roc_auc_list)

# %%
from hyperopt import fmin,tpe,Trials

trials=Trials()

best=fmin(fn=objective_func,
          space=xgb_search_space,
          algo=tpe.suggest,
          max_evals=50,
          trials=trials, rstate=np.random.default_rng(seed=30))

print('best:', best)
# Out:
# [0]	validation_0-auc:0.82172	validation_1-auc:0.79884
# [1]	validation_0-auc:0.81786	validation_1-auc:0.79065
# [2]	validation_0-auc:0.83200	validation_1-auc:0.80639
# [3]	validation_0-auc:0.83262	validation_1-auc:0.80856
# [4]	validation_0-auc:0.83831	validation_1-auc:0.81261
# [5]	validation_0-auc:0.84108	validation_1-auc:0.81553
# [6]	validation_0-auc:0.84370	validation_1-auc:0.81723
# [7]	validation_0-auc:0.84443	validation_1-auc:0.81700
# [8]	validation_0-auc:0.84520	validation_1-auc:0.81767
# [9]	validation_0-auc:0.84566	validation_1-auc:0.81679
# [10]	validation_0-auc:0.84624	validation_1-auc:0.81664
# [11]	validation_0-auc:0.84742	validation_1-auc:0.81684
# [12]	validation_0-auc:0.84819	validation_1-auc:0.81766
# [13]	validation_0-auc:0.84903	validation_1-auc:0.81816
# [14]	validation_0-auc:0.85123	validation_1-auc:0.81999
# [15]	validation_0-auc:0.85197	validation_1-auc:0.81995
# [16]	validation_0-auc:0.85391	validation_1-auc:0.82205
# [17]	validation_0-auc:0.85410	validation_1-auc:0.82182
# [18]	validation_0-auc:0.85488	validation_1-auc:0.82232
# [19]	validation_0-auc:0.85514	validation_1-auc:0.82235
# [20]	validation_0-auc:0.85652	validation_1-auc:0.82273
# [21]	validation_0-auc:0.85770	validation_1-auc:0.82464
# [22]	validation_0-auc:0.85896	validation_1-auc:0.82582
# [23]	validation_0-auc:0.86087	validation_1-auc:0.82688
# [24]	validation_0-auc:0.86219	validation_1-auc:0.82663
# [25]	validation_0-auc:0.86330	validation_1-auc:0.82701
# [26]	validation_0-auc:0.86481	validation_1-auc:0.82745
# [27]	validation_0-auc:0.86603	validation_1-auc:0.82829
# [28]	validation_0-auc:0.86716	validation_1-auc:0.82834
# [29]	validation_0-auc:0.86772	validation_1-auc:0.82849
# [30]	validation_0-auc:0.86834	validation_1-auc:0.82880
# [31]	validation_0-auc:0.86877	validation_1-auc:0.82976
# [32]	validation_0-auc:0.86973	validation_1-auc:0.83006
# [33]	validation_0-auc:0.87014	validation_1-auc:0.83069
# [34]	validation_0-auc:0.87058	validation_1-auc:0.83106
# [35]	validation_0-auc:0.87207	validation_1-auc:0.83109
# [36]	validation_0-auc:0.87259	validation_1-auc:0.83114
# [37]	validation_0-auc:0.87347	validation_1-auc:0.83175
# [38]	validation_0-auc:0.87510	validation_1-auc:0.83201
# [39]	validation_0-auc:0.87576	validation_1-auc:0.83214
# [40]	validation_0-auc:0.87670	validation_1-auc:0.83195
# [41]	validation_0-auc:0.87769	validation_1-auc:0.83207
# [42]	validation_0-auc:0.87805	validation_1-auc:0.83211
# [43]	validation_0-auc:0.87877	validation_1-auc:0.83274
# [44]	validation_0-auc:0.87961	validation_1-auc:0.83298
# [45]	validation_0-auc:0.88043	validation_1-auc:0.83326
# [46]	validation_0-auc:0.88131	validation_1-auc:0.83309
# [47]	validation_0-auc:0.88197	validation_1-auc:0.83306
# [48]	validation_0-auc:0.88269	validation_1-auc:0.83324
# [49]	validation_0-auc:0.88334	validation_1-auc:0.83351
# [50]	validation_0-auc:0.88419	validation_1-auc:0.83348
# [51]	validation_0-auc:0.88493	validation_1-auc:0.83323
# [52]	validation_0-auc:0.88540	validation_1-auc:0.83326
# [53]	validation_0-auc:0.88615	validation_1-auc:0.83348
# [54]	validation_0-auc:0.88658	validation_1-auc:0.83349
# [55]	validation_0-auc:0.88715	validation_1-auc:0.83327
# [56]	validation_0-auc:0.88770	validation_1-auc:0.83308
# [57]	validation_0-auc:0.88812	validation_1-auc:0.83308
# [58]	validation_0-auc:0.88872	validation_1-auc:0.83278
# [59]	validation_0-auc:0.88914	validation_1-auc:0.83279
# [60]	validation_0-auc:0.88931	validation_1-auc:0.83275
# [61]	validation_0-auc:0.88974	validation_1-auc:0.83254
# [62]	validation_0-auc:0.89025	validation_1-auc:0.83254
# [63]	validation_0-auc:0.89040	validation_1-auc:0.83231
# [64]	validation_0-auc:0.89063	validation_1-auc:0.83222
# [65]	validation_0-auc:0.89094	validation_1-auc:0.83264
# [66]	validation_0-auc:0.89150	validation_1-auc:0.83260
# [67]	validation_0-auc:0.89197	validation_1-auc:0.83282
# [68]	validation_0-auc:0.89252	validation_1-auc:0.83287
# [69]	validation_0-auc:0.89284	validation_1-auc:0.83300
# [70]	validation_0-auc:0.89306	validation_1-auc:0.83308
# [71]	validation_0-auc:0.89334	validation_1-auc:0.83316
# [72]	validation_0-auc:0.89355	validation_1-auc:0.83297
# [73]	validation_0-auc:0.89381	validation_1-auc:0.83286
# [74]	validation_0-auc:0.89405	validation_1-auc:0.83278
# [75]	validation_0-auc:0.89411	validation_1-auc:0.83267
# [76]	validation_0-auc:0.89419	validation_1-auc:0.83257
# [77]	validation_0-auc:0.89436	validation_1-auc:0.83267
# [78]	validation_0-auc:0.89450	validation_1-auc:0.83271
# [79]	validation_0-auc:0.89474	validation_1-auc:0.83264
# [0]	validation_0-auc:0.81542	validation_1-auc:0.80434
# [1]	validation_0-auc:0.81148	validation_1-auc:0.79829
# [2]	validation_0-auc:0.82478	validation_1-auc:0.81066
# [3]	validation_0-auc:0.83625	validation_1-auc:0.81982
# [4]	validation_0-auc:0.84091	validation_1-auc:0.82358
# [5]	validation_0-auc:0.84422	validation_1-auc:0.82703
# [6]	validation_0-auc:0.84540	validation_1-auc:0.82824
# [7]	validation_0-auc:0.84569	validation_1-auc:0.82678
# [8]	validation_0-auc:0.84701	validation_1-auc:0.82812
# [9]	validation_0-auc:0.84799	validation_1-auc:0.82852
# [10]	validation_0-auc:0.84954	validation_1-auc:0.82866
# [11]	validation_0-auc:0.85050	validation_1-auc:0.82920
# [12]	validation_0-auc:0.85098	validation_1-auc:0.82902
# [13]	validation_0-auc:0.85236	validation_1-auc:0.82970
# [14]	validation_0-auc:0.85354	validation_1-auc:0.82959
# [15]	validation_0-auc:0.85417	validation_1-auc:0.82975
# [16]	validation_0-auc:0.85580	validation_1-auc:0.82979
# [17]	validation_0-auc:0.85758	validation_1-auc:0.83010
# [18]	validation_0-auc:0.85851	validation_1-auc:0.83051
# [19]	validation_0-auc:0.85957	validation_1-auc:0.83152
# [20]	validation_0-auc:0.86110	validation_1-auc:0.83146
# [21]	validation_0-auc:0.86226	validation_1-auc:0.83125
# [22]	validation_0-auc:0.86311	validation_1-auc:0.83121
# [23]	validation_0-auc:0.86387	validation_1-auc:0.83173
# [24]	validation_0-auc:0.86505	validation_1-auc:0.83230
# [25]	validation_0-auc:0.86601	validation_1-auc:0.83208
# [26]	validation_0-auc:0.86673	validation_1-auc:0.83197
# [27]	validation_0-auc:0.86807	validation_1-auc:0.83226
# [28]	validation_0-auc:0.86946	validation_1-auc:0.83279
# [29]	validation_0-auc:0.86991	validation_1-auc:0.83304
# [30]	validation_0-auc:0.87022	validation_1-auc:0.83337
# [31]	validation_0-auc:0.87077	validation_1-auc:0.83384
# [32]	validation_0-auc:0.87164	validation_1-auc:0.83368
# [33]	validation_0-auc:0.87240	validation_1-auc:0.83425
# [34]	validation_0-auc:0.87308	validation_1-auc:0.83415
# [35]	validation_0-auc:0.87443	validation_1-auc:0.83425
# [36]	validation_0-auc:0.87491	validation_1-auc:0.83425
# [37]	validation_0-auc:0.87539	validation_1-auc:0.83440
# [38]	validation_0-auc:0.87620	validation_1-auc:0.83430
# [39]	validation_0-auc:0.87685	validation_1-auc:0.83491
# [40]	validation_0-auc:0.87789	validation_1-auc:0.83563
# [41]	validation_0-auc:0.87880	validation_1-auc:0.83565
# [42]	validation_0-auc:0.87905	validation_1-auc:0.83604
# [43]	validation_0-auc:0.87972	validation_1-auc:0.83629
# [44]	validation_0-auc:0.88061	validation_1-auc:0.83661
# [45]	validation_0-auc:0.88139	validation_1-auc:0.83634
# [46]	validation_0-auc:0.88256	validation_1-auc:0.83581
# [47]	validation_0-auc:0.88345	validation_1-auc:0.83641
# [48]	validation_0-auc:0.88420	validation_1-auc:0.83651
# [49]	validation_0-auc:0.88463	validation_1-auc:0.83687
# [50]	validation_0-auc:0.88574	validation_1-auc:0.83680
# [51]	validation_0-auc:0.88626	validation_1-auc:0.83672
# [52]	validation_0-auc:0.88657	validation_1-auc:0.83646
# [53]	validation_0-auc:0.88731	validation_1-auc:0.83637
# [54]	validation_0-auc:0.88735	validation_1-auc:0.83636
# [55]	validation_0-auc:0.88773	validation_1-auc:0.83647
# [56]	validation_0-auc:0.88858	validation_1-auc:0.83628
# [57]	validation_0-auc:0.88911	validation_1-auc:0.83649
# [58]	validation_0-auc:0.88948	validation_1-auc:0.83655
# [59]	validation_0-auc:0.89006	validation_1-auc:0.83667
# [60]	validation_0-auc:0.89030	validation_1-auc:0.83685
# [61]	validation_0-auc:0.89107	validation_1-auc:0.83692
# [62]	validation_0-auc:0.89126	validation_1-auc:0.83673
# [63]	validation_0-auc:0.89180	validation_1-auc:0.83658
# [64]	validation_0-auc:0.89227	validation_1-auc:0.83660
# [65]	validation_0-auc:0.89284	validation_1-auc:0.83671
# [66]	validation_0-auc:0.89346	validation_1-auc:0.83655
# [67]	validation_0-auc:0.89380	validation_1-auc:0.83659
# [68]	validation_0-auc:0.89415	validation_1-auc:0.83652
# [69]	validation_0-auc:0.89447	validation_1-auc:0.83666
# [70]	validation_0-auc:0.89515	validation_1-auc:0.83679
# [71]	validation_0-auc:0.89537	validation_1-auc:0.83681
# [72]	validation_0-auc:0.89587	validation_1-auc:0.83685
# [73]	validation_0-auc:0.89614	validation_1-auc:0.83659
# [74]	validation_0-auc:0.89636	validation_1-auc:0.83647
# [75]	validation_0-auc:0.89685	validation_1-auc:0.83640
# [76]	validation_0-auc:0.89724	validation_1-auc:0.83633
# [77]	validation_0-auc:0.89754	validation_1-auc:0.83631
# [78]	validation_0-auc:0.89772	validation_1-auc:0.83647
# [79]	validation_0-auc:0.89829	validation_1-auc:0.83634
# [80]	validation_0-auc:0.89847	validation_1-auc:0.83626
# [81]	validation_0-auc:0.89902	validation_1-auc:0.83625
# [82]	validation_0-auc:0.89922	validation_1-auc:0.83629
# [83]	validation_0-auc:0.89984	validation_1-auc:0.83649
# [84]	validation_0-auc:0.90012	validation_1-auc:0.83638
# [85]	validation_0-auc:0.90038	validation_1-auc:0.83649
# [86]	validation_0-auc:0.90121	validation_1-auc:0.83677
# [87]	validation_0-auc:0.90139	validation_1-auc:0.83670
# [88]	validation_0-auc:0.90154	validation_1-auc:0.83665
# [89]	validation_0-auc:0.90164	validation_1-auc:0.83666
# [90]	validation_0-auc:0.90194	validation_1-auc:0.83667
# [0]	validation_0-auc:0.82625	validation_1-auc:0.81018
# [1]	validation_0-auc:0.82001	validation_1-auc:0.80060
# [2]	validation_0-auc:0.83264	validation_1-auc:0.81371
# [3]	validation_0-auc:0.83826	validation_1-auc:0.81737
# [4]	validation_0-auc:0.84049	validation_1-auc:0.81730
# [5]	validation_0-auc:0.84199	validation_1-auc:0.81802
# [6]	validation_0-auc:0.84522	validation_1-auc:0.82191
# [7]	validation_0-auc:0.84696	validation_1-auc:0.82286
# [8]	validation_0-auc:0.84971	validation_1-auc:0.82442
# [9]	validation_0-auc:0.85166	validation_1-auc:0.82539
# [10]	validation_0-auc:0.85195	validation_1-auc:0.82502
# [11]	validation_0-auc:0.85293	validation_1-auc:0.82604
# [12]	validation_0-auc:0.85449	validation_1-auc:0.82635
# [13]	validation_0-auc:0.85476	validation_1-auc:0.82693
# [14]	validation_0-auc:0.85611	validation_1-auc:0.82798
# [15]	validation_0-auc:0.85696	validation_1-auc:0.82783
# [16]	validation_0-auc:0.85771	validation_1-auc:0.82780
# [17]	validation_0-auc:0.85814	validation_1-auc:0.82793
# [18]	validation_0-auc:0.85914	validation_1-auc:0.82869
# [19]	validation_0-auc:0.86025	validation_1-auc:0.82939
# [20]	validation_0-auc:0.86241	validation_1-auc:0.82935
# [21]	validation_0-auc:0.86380	validation_1-auc:0.83023
# [22]	validation_0-auc:0.86449	validation_1-auc:0.83003
# [23]	validation_0-auc:0.86472	validation_1-auc:0.83055
# [24]	validation_0-auc:0.86536	validation_1-auc:0.83062
# [25]	validation_0-auc:0.86582	validation_1-auc:0.83084
# [26]	validation_0-auc:0.86623	validation_1-auc:0.83112
# [27]	validation_0-auc:0.86798	validation_1-auc:0.83187
# [28]	validation_0-auc:0.86848	validation_1-auc:0.83230
# [29]	validation_0-auc:0.86884	validation_1-auc:0.83217
# [30]	validation_0-auc:0.86989	validation_1-auc:0.83336
# [31]	validation_0-auc:0.87110	validation_1-auc:0.83369
# [32]	validation_0-auc:0.87218	validation_1-auc:0.83388
# [33]	validation_0-auc:0.87282	validation_1-auc:0.83420
# [34]	validation_0-auc:0.87360	validation_1-auc:0.83423
# [35]	validation_0-auc:0.87494	validation_1-auc:0.83461
# [36]	validation_0-auc:0.87564	validation_1-auc:0.83500
# [37]	validation_0-auc:0.87623	validation_1-auc:0.83511
# [38]	validation_0-auc:0.87695	validation_1-auc:0.83479
# [39]	validation_0-auc:0.87780	validation_1-auc:0.83486
# [40]	validation_0-auc:0.87891	validation_1-auc:0.83479
# [41]	validation_0-auc:0.88016	validation_1-auc:0.83537
# [42]	validation_0-auc:0.88089	validation_1-auc:0.83535
# [43]	validation_0-auc:0.88157	validation_1-auc:0.83536
# [44]	validation_0-auc:0.88226	validation_1-auc:0.83603
# [45]	validation_0-auc:0.88335	validation_1-auc:0.83602
# [46]	validation_0-auc:0.88445	validation_1-auc:0.83613
# [47]	validation_0-auc:0.88499	validation_1-auc:0.83695
# [48]	validation_0-auc:0.88563	validation_1-auc:0.83662
# [49]	validation_0-auc:0.88615	validation_1-auc:0.83657
# [50]	validation_0-auc:0.88694	validation_1-auc:0.83660
# [51]	validation_0-auc:0.88726	validation_1-auc:0.83641
# [52]	validation_0-auc:0.88809	validation_1-auc:0.83693
# [53]	validation_0-auc:0.88836	validation_1-auc:0.83719
# [54]	validation_0-auc:0.88871	validation_1-auc:0.83736
# [55]	validation_0-auc:0.88898	validation_1-auc:0.83747
# [56]	validation_0-auc:0.89009	validation_1-auc:0.83720
# [57]	validation_0-auc:0.89086	validation_1-auc:0.83753
# [58]	validation_0-auc:0.89129	validation_1-auc:0.83770
# [59]	validation_0-auc:0.89163	validation_1-auc:0.83775
# [60]	validation_0-auc:0.89192	validation_1-auc:0.83782
# [61]	validation_0-auc:0.89243	validation_1-auc:0.83742
# [62]	validation_0-auc:0.89277	validation_1-auc:0.83755
# [63]	validation_0-auc:0.89354	validation_1-auc:0.83734
# [64]	validation_0-auc:0.89392	validation_1-auc:0.83769
# [65]	validation_0-auc:0.89450	validation_1-auc:0.83761
# [66]	validation_0-auc:0.89480	validation_1-auc:0.83763
# [67]	validation_0-auc:0.89497	validation_1-auc:0.83778
# [68]	validation_0-auc:0.89522	validation_1-auc:0.83777
# [69]	validation_0-auc:0.89551	validation_1-auc:0.83781
# [70]	validation_0-auc:0.89573	validation_1-auc:0.83792
# [71]	validation_0-auc:0.89592	validation_1-auc:0.83809
# [72]	validation_0-auc:0.89618	validation_1-auc:0.83801
# [73]	validation_0-auc:0.89661	validation_1-auc:0.83785
# [74]	validation_0-auc:0.89691	validation_1-auc:0.83788
# [75]	validation_0-auc:0.89707	validation_1-auc:0.83792
# [76]	validation_0-auc:0.89748	validation_1-auc:0.83803
# [77]	validation_0-auc:0.89774	validation_1-auc:0.83817
# [78]	validation_0-auc:0.89833	validation_1-auc:0.83819
# [79]	validation_0-auc:0.89860	validation_1-auc:0.83828
# [80]	validation_0-auc:0.89884	validation_1-auc:0.83840
# [81]	validation_0-auc:0.89925	validation_1-auc:0.83857
# [82]	validation_0-auc:0.89983	validation_1-auc:0.83879
# [83]	validation_0-auc:0.90045	validation_1-auc:0.83873
# [84]	validation_0-auc:0.90067	validation_1-auc:0.83879
# [85]	validation_0-auc:0.90089	validation_1-auc:0.83887
# [86]	validation_0-auc:0.90133	validation_1-auc:0.83909
# [87]	validation_0-auc:0.90153	validation_1-auc:0.83898
# [88]	validation_0-auc:0.90168	validation_1-auc:0.83902
# [89]	validation_0-auc:0.90174	validation_1-auc:0.83893
# [90]	validation_0-auc:0.90214	validation_1-auc:0.83878
# [91]	validation_0-auc:0.90236	validation_1-auc:0.83884
# [92]	validation_0-auc:0.90257	validation_1-auc:0.83879
# [93]	validation_0-auc:0.90268	validation_1-auc:0.83873
# [94]	validation_0-auc:0.90282	validation_1-auc:0.83887
# [95]	validation_0-auc:0.90303	validation_1-auc:0.83877
# [96]	validation_0-auc:0.90319	validation_1-auc:0.83859
# [97]	validation_0-auc:0.90345	validation_1-auc:0.83862
# [98]	validation_0-auc:0.90351	validation_1-auc:0.83857
# [99]	validation_0-auc:0.90372	validation_1-auc:0.83855
# [0]	validation_0-auc:0.83260	validation_1-auc:0.79842
# [1]	validation_0-auc:0.82759	validation_1-auc:0.78831
# [2]	validation_0-auc:0.84193	validation_1-auc:0.80084
# [3]	validation_0-auc:0.84654	validation_1-auc:0.80433
# [4]	validation_0-auc:0.85108	validation_1-auc:0.80695
# [5]	validation_0-auc:0.85121	validation_1-auc:0.80484
# [6]	validation_0-auc:0.85543	validation_1-auc:0.80841
# [7]	validation_0-auc:0.85770	validation_1-auc:0.80969
# [8]	validation_0-auc:0.85891	validation_1-auc:0.81099
# [9]	validation_0-auc:0.86334	validation_1-auc:0.81310
# [10]	validation_0-auc:0.86130	validation_1-auc:0.80880
# [11]	validation_0-auc:0.86620	validation_1-auc:0.81248
# [12]	validation_0-auc:0.86845	validation_1-auc:0.81455
# [13]	validation_0-auc:0.87002	validation_1-auc:0.81234
# [14]	validation_0-auc:0.87243	validation_1-auc:0.81466
# [15]	validation_0-auc:0.87271	validation_1-auc:0.81302
# [16]	validation_0-auc:0.87447	validation_1-auc:0.81184
# [17]	validation_0-auc:0.87625	validation_1-auc:0.81057
# [18]	validation_0-auc:0.87886	validation_1-auc:0.81367
# [19]	validation_0-auc:0.88470	validation_1-auc:0.81568
# [20]	validation_0-auc:0.88928	validation_1-auc:0.81658
# [21]	validation_0-auc:0.88885	validation_1-auc:0.81376
# [22]	validation_0-auc:0.89235	validation_1-auc:0.81611
# [23]	validation_0-auc:0.89332	validation_1-auc:0.81752
# [24]	validation_0-auc:0.89387	validation_1-auc:0.81613
# [25]	validation_0-auc:0.89743	validation_1-auc:0.81823
# [26]	validation_0-auc:0.89985	validation_1-auc:0.81965
# [27]	validation_0-auc:0.90146	validation_1-auc:0.81820
# [28]	validation_0-auc:0.90342	validation_1-auc:0.81732
# [29]	validation_0-auc:0.90403	validation_1-auc:0.81902
# [30]	validation_0-auc:0.90535	validation_1-auc:0.82013
# [31]	validation_0-auc:0.90579	validation_1-auc:0.81838
# [32]	validation_0-auc:0.90768	validation_1-auc:0.81782
# [33]	validation_0-auc:0.91007	validation_1-auc:0.81896
# [34]	validation_0-auc:0.91145	validation_1-auc:0.81843
# [35]	validation_0-auc:0.91191	validation_1-auc:0.81798
# [36]	validation_0-auc:0.91375	validation_1-auc:0.81946
# [37]	validation_0-auc:0.91411	validation_1-auc:0.81825
# [38]	validation_0-auc:0.91465	validation_1-auc:0.81812
# [39]	validation_0-auc:0.91531	validation_1-auc:0.81659
# [40]	validation_0-auc:0.91847	validation_1-auc:0.81776
# [41]	validation_0-auc:0.92163	validation_1-auc:0.81929
# [42]	validation_0-auc:0.92263	validation_1-auc:0.82024
# [43]	validation_0-auc:0.92512	validation_1-auc:0.82163
# [44]	validation_0-auc:0.92697	validation_1-auc:0.82261
# [45]	validation_0-auc:0.92895	validation_1-auc:0.82384
# [46]	validation_0-auc:0.92952	validation_1-auc:0.82316
# [47]	validation_0-auc:0.93022	validation_1-auc:0.82333
# [48]	validation_0-auc:0.93104	validation_1-auc:0.82397
# [49]	validation_0-auc:0.93209	validation_1-auc:0.82511
# [50]	validation_0-auc:0.93279	validation_1-auc:0.82427
# [51]	validation_0-auc:0.93420	validation_1-auc:0.82513
# [52]	validation_0-auc:0.93480	validation_1-auc:0.82536
# [53]	validation_0-auc:0.93607	validation_1-auc:0.82559
# [54]	validation_0-auc:0.93643	validation_1-auc:0.82577
# [55]	validation_0-auc:0.93716	validation_1-auc:0.82559
# [56]	validation_0-auc:0.93820	validation_1-auc:0.82497
# [57]	validation_0-auc:0.93843	validation_1-auc:0.82479
# [58]	validation_0-auc:0.93939	validation_1-auc:0.82527
# [59]	validation_0-auc:0.94001	validation_1-auc:0.82567
# [60]	validation_0-auc:0.94076	validation_1-auc:0.82610
# [61]	validation_0-auc:0.94095	validation_1-auc:0.82556
# [62]	validation_0-auc:0.94227	validation_1-auc:0.82543
# [63]	validation_0-auc:0.94307	validation_1-auc:0.82471
# [64]	validation_0-auc:0.94342	validation_1-auc:0.82422
# [65]	validation_0-auc:0.94470	validation_1-auc:0.82431
# [66]	validation_0-auc:0.94531	validation_1-auc:0.82398
# [67]	validation_0-auc:0.94554	validation_1-auc:0.82402
# [68]	validation_0-auc:0.94591	validation_1-auc:0.82357
# [69]	validation_0-auc:0.94667	validation_1-auc:0.82380
# [70]	validation_0-auc:0.94767	validation_1-auc:0.82406
# [71]	validation_0-auc:0.94830	validation_1-auc:0.82398
# [72]	validation_0-auc:0.94847	validation_1-auc:0.82370
# [73]	validation_0-auc:0.94917	validation_1-auc:0.82328
# [74]	validation_0-auc:0.94972	validation_1-auc:0.82281
# [75]	validation_0-auc:0.95024	validation_1-auc:0.82239
# [76]	validation_0-auc:0.95070	validation_1-auc:0.82220
# [77]	validation_0-auc:0.95144	validation_1-auc:0.82230
# [78]	validation_0-auc:0.95159	validation_1-auc:0.82207
# [79]	validation_0-auc:0.95196	validation_1-auc:0.82254
# [80]	validation_0-auc:0.95240	validation_1-auc:0.82263
# [81]	validation_0-auc:0.95254	validation_1-auc:0.82280
# [82]	validation_0-auc:0.95287	validation_1-auc:0.82269
# [83]	validation_0-auc:0.95330	validation_1-auc:0.82265
# [84]	validation_0-auc:0.95342	validation_1-auc:0.82277
# [85]	validation_0-auc:0.95401	validation_1-auc:0.82343
# [86]	validation_0-auc:0.95451	validation_1-auc:0.82342
# [87]	validation_0-auc:0.95478	validation_1-auc:0.82359
# [88]	validation_0-auc:0.95485	validation_1-auc:0.82339
# [89]	validation_0-auc:0.95519	validation_1-auc:0.82368
# [0]	validation_0-auc:0.82429	validation_1-auc:0.80586
# [1]	validation_0-auc:0.81765	validation_1-auc:0.79795
# [2]	validation_0-auc:0.83724	validation_1-auc:0.81693
# [3]	validation_0-auc:0.84597	validation_1-auc:0.82184
# [4]	validation_0-auc:0.84954	validation_1-auc:0.82498
# [5]	validation_0-auc:0.85617	validation_1-auc:0.82332
# [6]	validation_0-auc:0.85969	validation_1-auc:0.82426
# [7]	validation_0-auc:0.86208	validation_1-auc:0.82496
# [8]	validation_0-auc:0.86388	validation_1-auc:0.82634
# [9]	validation_0-auc:0.86805	validation_1-auc:0.82521
# [10]	validation_0-auc:0.86748	validation_1-auc:0.82199
# [11]	validation_0-auc:0.87147	validation_1-auc:0.82317
# [12]	validation_0-auc:0.87486	validation_1-auc:0.82542
# [13]	validation_0-auc:0.87804	validation_1-auc:0.82372
# [14]	validation_0-auc:0.88060	validation_1-auc:0.82477
# [15]	validation_0-auc:0.88071	validation_1-auc:0.82357
# [16]	validation_0-auc:0.88046	validation_1-auc:0.82144
# [17]	validation_0-auc:0.88191	validation_1-auc:0.82101
# [18]	validation_0-auc:0.88404	validation_1-auc:0.82270
# [19]	validation_0-auc:0.88850	validation_1-auc:0.82427
# [20]	validation_0-auc:0.89307	validation_1-auc:0.82572
# [21]	validation_0-auc:0.89335	validation_1-auc:0.82467
# [22]	validation_0-auc:0.89669	validation_1-auc:0.82636
# [23]	validation_0-auc:0.89819	validation_1-auc:0.82683
# [24]	validation_0-auc:0.89848	validation_1-auc:0.82608
# [25]	validation_0-auc:0.90093	validation_1-auc:0.82633
# [26]	validation_0-auc:0.90341	validation_1-auc:0.82706
# [27]	validation_0-auc:0.90500	validation_1-auc:0.82561
# [28]	validation_0-auc:0.90626	validation_1-auc:0.82454
# [29]	validation_0-auc:0.90683	validation_1-auc:0.82519
# [30]	validation_0-auc:0.90855	validation_1-auc:0.82527
# [31]	validation_0-auc:0.90909	validation_1-auc:0.82450
# [32]	validation_0-auc:0.91033	validation_1-auc:0.82339
# [33]	validation_0-auc:0.91188	validation_1-auc:0.82457
# [34]	validation_0-auc:0.91319	validation_1-auc:0.82408
# [35]	validation_0-auc:0.91361	validation_1-auc:0.82299
# [36]	validation_0-auc:0.91549	validation_1-auc:0.82375
# [37]	validation_0-auc:0.91557	validation_1-auc:0.82357
# [38]	validation_0-auc:0.91624	validation_1-auc:0.82323
# [39]	validation_0-auc:0.91621	validation_1-auc:0.82205
# [40]	validation_0-auc:0.91946	validation_1-auc:0.82288
# [41]	validation_0-auc:0.92147	validation_1-auc:0.82372
# [42]	validation_0-auc:0.92232	validation_1-auc:0.82544
# [43]	validation_0-auc:0.92459	validation_1-auc:0.82683
# [44]	validation_0-auc:0.92642	validation_1-auc:0.82778
# [45]	validation_0-auc:0.92799	validation_1-auc:0.82872
# [46]	validation_0-auc:0.92813	validation_1-auc:0.82813
# [47]	validation_0-auc:0.92926	validation_1-auc:0.82904
# [48]	validation_0-auc:0.93002	validation_1-auc:0.82962
# [49]	validation_0-auc:0.93148	validation_1-auc:0.82976
# [50]	validation_0-auc:0.93164	validation_1-auc:0.82891
# [51]	validation_0-auc:0.93320	validation_1-auc:0.82900
# [52]	validation_0-auc:0.93406	validation_1-auc:0.82900
# [53]	validation_0-auc:0.93507	validation_1-auc:0.82886
# [54]	validation_0-auc:0.93545	validation_1-auc:0.82920
# [55]	validation_0-auc:0.93658	validation_1-auc:0.82964
# [56]	validation_0-auc:0.93769	validation_1-auc:0.82937
# [57]	validation_0-auc:0.93800	validation_1-auc:0.82884
# [58]	validation_0-auc:0.93882	validation_1-auc:0.82933
# [59]	validation_0-auc:0.93960	validation_1-auc:0.82923
# [60]	validation_0-auc:0.94033	validation_1-auc:0.82957
# [61]	validation_0-auc:0.94056	validation_1-auc:0.82979
# [62]	validation_0-auc:0.94210	validation_1-auc:0.82986
# [63]	validation_0-auc:0.94304	validation_1-auc:0.82942
# [64]	validation_0-auc:0.94335	validation_1-auc:0.82938
# [65]	validation_0-auc:0.94464	validation_1-auc:0.82976
# [66]	validation_0-auc:0.94537	validation_1-auc:0.82954
# [67]	validation_0-auc:0.94578	validation_1-auc:0.82991
# [68]	validation_0-auc:0.94600	validation_1-auc:0.82944
# [69]	validation_0-auc:0.94630	validation_1-auc:0.82985
# [70]	validation_0-auc:0.94751	validation_1-auc:0.82986
# [71]	validation_0-auc:0.94782	validation_1-auc:0.83019
# [72]	validation_0-auc:0.94788	validation_1-auc:0.83008
# [73]	validation_0-auc:0.94853	validation_1-auc:0.82979
# [74]	validation_0-auc:0.94910	validation_1-auc:0.82947
# [75]	validation_0-auc:0.94993	validation_1-auc:0.82888
# [76]	validation_0-auc:0.95071	validation_1-auc:0.82868
# [77]	validation_0-auc:0.95172	validation_1-auc:0.82856
# [78]	validation_0-auc:0.95193	validation_1-auc:0.82835
# [79]	validation_0-auc:0.95226	validation_1-auc:0.82838
# [80]	validation_0-auc:0.95289	validation_1-auc:0.82824
# [81]	validation_0-auc:0.95298	validation_1-auc:0.82877
# [82]	validation_0-auc:0.95324	validation_1-auc:0.82885
# [83]	validation_0-auc:0.95398	validation_1-auc:0.82837
# [84]	validation_0-auc:0.95404	validation_1-auc:0.82857
# [85]	validation_0-auc:0.95449	validation_1-auc:0.82878
# [86]	validation_0-auc:0.95512	validation_1-auc:0.82901
# [87]	validation_0-auc:0.95549	validation_1-auc:0.82910
# [88]	validation_0-auc:0.95562	validation_1-auc:0.82910
# [89]	validation_0-auc:0.95605	validation_1-auc:0.82939
# [90]	validation_0-auc:0.95638	validation_1-auc:0.82937
# [91]	validation_0-auc:0.95642	validation_1-auc:0.82939
# [92]	validation_0-auc:0.95683	validation_1-auc:0.82960
# [93]	validation_0-auc:0.95731	validation_1-auc:0.82967
# [94]	validation_0-auc:0.95734	validation_1-auc:0.82994
# [95]	validation_0-auc:0.95741	validation_1-auc:0.83008
# [96]	validation_0-auc:0.95764	validation_1-auc:0.82997
# [97]	validation_0-auc:0.95812	validation_1-auc:0.83013
# [98]	validation_0-auc:0.95838	validation_1-auc:0.83020
# [99]	validation_0-auc:0.95857	validation_1-auc:0.83023
# [0]	validation_0-auc:0.83818	validation_1-auc:0.80637
# [1]	validation_0-auc:0.83425	validation_1-auc:0.80140
# [2]	validation_0-auc:0.84845	validation_1-auc:0.81267
# [3]	validation_0-auc:0.85347	validation_1-auc:0.81467
# [4]	validation_0-auc:0.85697	validation_1-auc:0.81757
# [5]	validation_0-auc:0.85862	validation_1-auc:0.81537
# [6]	validation_0-auc:0.86040	validation_1-auc:0.81746
# [7]	validation_0-auc:0.86301	validation_1-auc:0.81895
# [8]	validation_0-auc:0.86692	validation_1-auc:0.82208
# [9]	validation_0-auc:0.86903	validation_1-auc:0.82152
# [10]	validation_0-auc:0.86973	validation_1-auc:0.81987
# [11]	validation_0-auc:0.87334	validation_1-auc:0.82102
# [12]	validation_0-auc:0.87790	validation_1-auc:0.82185
# [13]	validation_0-auc:0.87901	validation_1-auc:0.82207
# [14]	validation_0-auc:0.88275	validation_1-auc:0.82326
# [15]	validation_0-auc:0.88362	validation_1-auc:0.82203
# [16]	validation_0-auc:0.88272	validation_1-auc:0.82161
# [17]	validation_0-auc:0.88363	validation_1-auc:0.82000
# [18]	validation_0-auc:0.88538	validation_1-auc:0.82197
# [19]	validation_0-auc:0.88937	validation_1-auc:0.82229
# [20]	validation_0-auc:0.89261	validation_1-auc:0.82297
# [21]	validation_0-auc:0.89326	validation_1-auc:0.82190
# [22]	validation_0-auc:0.89673	validation_1-auc:0.82219
# [23]	validation_0-auc:0.89778	validation_1-auc:0.82348
# [24]	validation_0-auc:0.89805	validation_1-auc:0.82152
# [25]	validation_0-auc:0.90028	validation_1-auc:0.82239
# [26]	validation_0-auc:0.90337	validation_1-auc:0.82295
# [27]	validation_0-auc:0.90552	validation_1-auc:0.82198
# [28]	validation_0-auc:0.90706	validation_1-auc:0.82085
# [29]	validation_0-auc:0.90917	validation_1-auc:0.82174
# [30]	validation_0-auc:0.91023	validation_1-auc:0.82242
# [31]	validation_0-auc:0.91053	validation_1-auc:0.82139
# [32]	validation_0-auc:0.91141	validation_1-auc:0.82127
# [33]	validation_0-auc:0.91246	validation_1-auc:0.82231
# [34]	validation_0-auc:0.91350	validation_1-auc:0.82127
# [35]	validation_0-auc:0.91472	validation_1-auc:0.82031
# [36]	validation_0-auc:0.91635	validation_1-auc:0.82178
# [37]	validation_0-auc:0.91687	validation_1-auc:0.82160
# [38]	validation_0-auc:0.91806	validation_1-auc:0.82094
# [39]	validation_0-auc:0.91840	validation_1-auc:0.82040
# [40]	validation_0-auc:0.92083	validation_1-auc:0.82180
# [41]	validation_0-auc:0.92359	validation_1-auc:0.82352
# [42]	validation_0-auc:0.92406	validation_1-auc:0.82504
# [43]	validation_0-auc:0.92662	validation_1-auc:0.82590
# [44]	validation_0-auc:0.92812	validation_1-auc:0.82667
# [45]	validation_0-auc:0.92992	validation_1-auc:0.82712
# [46]	validation_0-auc:0.93046	validation_1-auc:0.82648
# [47]	validation_0-auc:0.93082	validation_1-auc:0.82735
# [48]	validation_0-auc:0.93158	validation_1-auc:0.82759
# [49]	validation_0-auc:0.93284	validation_1-auc:0.82789
# [50]	validation_0-auc:0.93321	validation_1-auc:0.82801
# [51]	validation_0-auc:0.93479	validation_1-auc:0.82893
# [52]	validation_0-auc:0.93527	validation_1-auc:0.82932
# [53]	validation_0-auc:0.93666	validation_1-auc:0.82939
# [54]	validation_0-auc:0.93685	validation_1-auc:0.82974
# [55]	validation_0-auc:0.93741	validation_1-auc:0.83021
# [56]	validation_0-auc:0.93857	validation_1-auc:0.83008
# [57]	validation_0-auc:0.93876	validation_1-auc:0.82978
# [58]	validation_0-auc:0.93944	validation_1-auc:0.82997
# [59]	validation_0-auc:0.94038	validation_1-auc:0.82980
# [60]	validation_0-auc:0.94101	validation_1-auc:0.82984
# [61]	validation_0-auc:0.94125	validation_1-auc:0.82986
# [62]	validation_0-auc:0.94275	validation_1-auc:0.82997
# [63]	validation_0-auc:0.94417	validation_1-auc:0.82956
# [64]	validation_0-auc:0.94444	validation_1-auc:0.82939
# [65]	validation_0-auc:0.94567	validation_1-auc:0.82958
# [66]	validation_0-auc:0.94650	validation_1-auc:0.82937
# [67]	validation_0-auc:0.94676	validation_1-auc:0.83000
# [68]	validation_0-auc:0.94701	validation_1-auc:0.82982
# [69]	validation_0-auc:0.94729	validation_1-auc:0.82979
# [70]	validation_0-auc:0.94818	validation_1-auc:0.83019
# [71]	validation_0-auc:0.94839	validation_1-auc:0.83060
# [72]	validation_0-auc:0.94862	validation_1-auc:0.83044
# [73]	validation_0-auc:0.94949	validation_1-auc:0.82994
# [74]	validation_0-auc:0.95015	validation_1-auc:0.83016
# [75]	validation_0-auc:0.95097	validation_1-auc:0.82963
# [76]	validation_0-auc:0.95160	validation_1-auc:0.82890
# [77]	validation_0-auc:0.95233	validation_1-auc:0.82901
# [78]	validation_0-auc:0.95248	validation_1-auc:0.82899
# [79]	validation_0-auc:0.95263	validation_1-auc:0.82908
# [80]	validation_0-auc:0.95335	validation_1-auc:0.82876
# [81]	validation_0-auc:0.95354	validation_1-auc:0.82891
# [82]	validation_0-auc:0.95364	validation_1-auc:0.82905
# [83]	validation_0-auc:0.95426	validation_1-auc:0.82885
# [84]	validation_0-auc:0.95431	validation_1-auc:0.82882
# [85]	validation_0-auc:0.95458	validation_1-auc:0.82902
# [86]	validation_0-auc:0.95532	validation_1-auc:0.82911
# [87]	validation_0-auc:0.95550	validation_1-auc:0.82932
# [88]	validation_0-auc:0.95571	validation_1-auc:0.82893
# [89]	validation_0-auc:0.95609	validation_1-auc:0.82955
# [90]	validation_0-auc:0.95638	validation_1-auc:0.82915
# [91]	validation_0-auc:0.95661	validation_1-auc:0.82924
# [92]	validation_0-auc:0.95702	validation_1-auc:0.82954
# [93]	validation_0-auc:0.95742	validation_1-auc:0.82964
# [94]	validation_0-auc:0.95748	validation_1-auc:0.82975
# [95]	validation_0-auc:0.95754	validation_1-auc:0.83025
# [96]	validation_0-auc:0.95781	validation_1-auc:0.83015
# [97]	validation_0-auc:0.95824	validation_1-auc:0.83015
# [98]	validation_0-auc:0.95856	validation_1-auc:0.83025
# [99]	validation_0-auc:0.95863	validation_1-auc:0.83009
# [0]	validation_0-auc:0.83136	validation_1-auc:0.80008
# [1]	validation_0-auc:0.82739	validation_1-auc:0.79045
# [2]	validation_0-auc:0.84355	validation_1-auc:0.80354
# [3]	validation_0-auc:0.85105	validation_1-auc:0.80923
# [4]	validation_0-auc:0.85863	validation_1-auc:0.81146
# [5]	validation_0-auc:0.86369	validation_1-auc:0.81360
# [6]	validation_0-auc:0.86608	validation_1-auc:0.81551
# [7]	validation_0-auc:0.87100	validation_1-auc:0.81558
# [8]	validation_0-auc:0.87634	validation_1-auc:0.81740
# [9]	validation_0-auc:0.88160	validation_1-auc:0.81815
# [10]	validation_0-auc:0.88629	validation_1-auc:0.81959
# [11]	validation_0-auc:0.89074	validation_1-auc:0.82288
# [12]	validation_0-auc:0.89404	validation_1-auc:0.82269
# [13]	validation_0-auc:0.89956	validation_1-auc:0.82499
# [14]	validation_0-auc:0.90236	validation_1-auc:0.82637
# [15]	validation_0-auc:0.90659	validation_1-auc:0.82450
# [16]	validation_0-auc:0.91053	validation_1-auc:0.82496
# [17]	validation_0-auc:0.91180	validation_1-auc:0.82457
# [18]	validation_0-auc:0.91587	validation_1-auc:0.82456
# [19]	validation_0-auc:0.91882	validation_1-auc:0.82517
# [20]	validation_0-auc:0.92163	validation_1-auc:0.82655
# [21]	validation_0-auc:0.92362	validation_1-auc:0.82330
# [22]	validation_0-auc:0.92759	validation_1-auc:0.82419
# [23]	validation_0-auc:0.93104	validation_1-auc:0.82398
# [24]	validation_0-auc:0.93370	validation_1-auc:0.82386
# [25]	validation_0-auc:0.93518	validation_1-auc:0.82392
# [26]	validation_0-auc:0.93753	validation_1-auc:0.82422
# [27]	validation_0-auc:0.93945	validation_1-auc:0.82389
# [28]	validation_0-auc:0.94143	validation_1-auc:0.82436
# [29]	validation_0-auc:0.94174	validation_1-auc:0.82456
# [30]	validation_0-auc:0.94250	validation_1-auc:0.82424
# [31]	validation_0-auc:0.94383	validation_1-auc:0.82410
# [32]	validation_0-auc:0.94515	validation_1-auc:0.82388
# [33]	validation_0-auc:0.94564	validation_1-auc:0.82402
# [34]	validation_0-auc:0.94690	validation_1-auc:0.82315
# [35]	validation_0-auc:0.94783	validation_1-auc:0.82298
# [36]	validation_0-auc:0.94833	validation_1-auc:0.82378
# [37]	validation_0-auc:0.94898	validation_1-auc:0.82383
# [38]	validation_0-auc:0.94956	validation_1-auc:0.82300
# [39]	validation_0-auc:0.95017	validation_1-auc:0.82213
# [40]	validation_0-auc:0.95103	validation_1-auc:0.82204
# [41]	validation_0-auc:0.95162	validation_1-auc:0.82216
# [42]	validation_0-auc:0.95182	validation_1-auc:0.82239
# [43]	validation_0-auc:0.95251	validation_1-auc:0.82215
# [44]	validation_0-auc:0.95256	validation_1-auc:0.82195
# [45]	validation_0-auc:0.95283	validation_1-auc:0.82237
# [46]	validation_0-auc:0.95317	validation_1-auc:0.82214
# [47]	validation_0-auc:0.95376	validation_1-auc:0.82213
# [48]	validation_0-auc:0.95387	validation_1-auc:0.82204
# [49]	validation_0-auc:0.95398	validation_1-auc:0.82215
# [50]	validation_0-auc:0.95429	validation_1-auc:0.82194
# [0]	validation_0-auc:0.82516	validation_1-auc:0.80483
# [1]	validation_0-auc:0.82094	validation_1-auc:0.79878
# [2]	validation_0-auc:0.84812	validation_1-auc:0.81814
# [3]	validation_0-auc:0.85704	validation_1-auc:0.82182
# [4]	validation_0-auc:0.86396	validation_1-auc:0.82362
# [5]	validation_0-auc:0.86761	validation_1-auc:0.82593
# [6]	validation_0-auc:0.86911	validation_1-auc:0.82686
# [7]	validation_0-auc:0.87338	validation_1-auc:0.82811
# [8]	validation_0-auc:0.87867	validation_1-auc:0.82717
# [9]	validation_0-auc:0.88509	validation_1-auc:0.82499
# [10]	validation_0-auc:0.89294	validation_1-auc:0.82583
# [11]	validation_0-auc:0.89581	validation_1-auc:0.82603
# [12]	validation_0-auc:0.89920	validation_1-auc:0.82715
# [13]	validation_0-auc:0.90212	validation_1-auc:0.82719
# [14]	validation_0-auc:0.90314	validation_1-auc:0.82806
# [15]	validation_0-auc:0.90698	validation_1-auc:0.82732
# [16]	validation_0-auc:0.91092	validation_1-auc:0.82850
# [17]	validation_0-auc:0.91275	validation_1-auc:0.82648
# [18]	validation_0-auc:0.91784	validation_1-auc:0.82808
# [19]	validation_0-auc:0.92100	validation_1-auc:0.82983
# [20]	validation_0-auc:0.92389	validation_1-auc:0.83039
# [21]	validation_0-auc:0.92510	validation_1-auc:0.82876
# [22]	validation_0-auc:0.92902	validation_1-auc:0.82740
# [23]	validation_0-auc:0.93210	validation_1-auc:0.82694
# [24]	validation_0-auc:0.93409	validation_1-auc:0.82725
# [25]	validation_0-auc:0.93616	validation_1-auc:0.82798
# [26]	validation_0-auc:0.93837	validation_1-auc:0.82665
# [27]	validation_0-auc:0.94022	validation_1-auc:0.82587
# [28]	validation_0-auc:0.94241	validation_1-auc:0.82764
# [29]	validation_0-auc:0.94362	validation_1-auc:0.82784
# [30]	validation_0-auc:0.94424	validation_1-auc:0.82908
# [31]	validation_0-auc:0.94516	validation_1-auc:0.82907
# [32]	validation_0-auc:0.94664	validation_1-auc:0.82820
# [33]	validation_0-auc:0.94715	validation_1-auc:0.82922
# [34]	validation_0-auc:0.94887	validation_1-auc:0.82857
# [35]	validation_0-auc:0.94986	validation_1-auc:0.82902
# [36]	validation_0-auc:0.95036	validation_1-auc:0.82920
# [37]	validation_0-auc:0.95120	validation_1-auc:0.82925
# [38]	validation_0-auc:0.95182	validation_1-auc:0.82878
# [39]	validation_0-auc:0.95207	validation_1-auc:0.82852
# [40]	validation_0-auc:0.95267	validation_1-auc:0.82850
# [41]	validation_0-auc:0.95310	validation_1-auc:0.82854
# [42]	validation_0-auc:0.95316	validation_1-auc:0.82918
# [43]	validation_0-auc:0.95348	validation_1-auc:0.82941
# [44]	validation_0-auc:0.95380	validation_1-auc:0.82960
# [45]	validation_0-auc:0.95464	validation_1-auc:0.82962
# [46]	validation_0-auc:0.95503	validation_1-auc:0.82986
# [47]	validation_0-auc:0.95557	validation_1-auc:0.82999
# [48]	validation_0-auc:0.95623	validation_1-auc:0.83045
# [49]	validation_0-auc:0.95657	validation_1-auc:0.83025
# [50]	validation_0-auc:0.95669	validation_1-auc:0.82998
# [51]	validation_0-auc:0.95719	validation_1-auc:0.82958
# [52]	validation_0-auc:0.95736	validation_1-auc:0.82964
# [53]	validation_0-auc:0.95760	validation_1-auc:0.82968
# [54]	validation_0-auc:0.95794	validation_1-auc:0.82978
# [55]	validation_0-auc:0.95821	validation_1-auc:0.82995
# [56]	validation_0-auc:0.95850	validation_1-auc:0.82982
# [57]	validation_0-auc:0.95861	validation_1-auc:0.82965
# [58]	validation_0-auc:0.95890	validation_1-auc:0.82974
# [59]	validation_0-auc:0.95951	validation_1-auc:0.82973
# [60]	validation_0-auc:0.95959	validation_1-auc:0.82980
# [61]	validation_0-auc:0.95978	validation_1-auc:0.82999
# [62]	validation_0-auc:0.96037	validation_1-auc:0.82994
# [63]	validation_0-auc:0.96067	validation_1-auc:0.83007
# [64]	validation_0-auc:0.96114	validation_1-auc:0.83000
# [65]	validation_0-auc:0.96134	validation_1-auc:0.82986
# [66]	validation_0-auc:0.96146	validation_1-auc:0.82969
# [67]	validation_0-auc:0.96152	validation_1-auc:0.82952
# [68]	validation_0-auc:0.96161	validation_1-auc:0.82972
# [69]	validation_0-auc:0.96172	validation_1-auc:0.82934
# [70]	validation_0-auc:0.96184	validation_1-auc:0.82928
# [71]	validation_0-auc:0.96186	validation_1-auc:0.82918
# [72]	validation_0-auc:0.96203	validation_1-auc:0.82918
# [73]	validation_0-auc:0.96212	validation_1-auc:0.82912
# [74]	validation_0-auc:0.96220	validation_1-auc:0.82908
# [75]	validation_0-auc:0.96245	validation_1-auc:0.82869
# [76]	validation_0-auc:0.96283	validation_1-auc:0.82881
# [77]	validation_0-auc:0.96305	validation_1-auc:0.82866
# [78]	validation_0-auc:0.96310	validation_1-auc:0.82858
# [0]	validation_0-auc:0.83715	validation_1-auc:0.80811
# [1]	validation_0-auc:0.83842	validation_1-auc:0.80646
# [2]	validation_0-auc:0.84993	validation_1-auc:0.81566
# [3]	validation_0-auc:0.86042	validation_1-auc:0.81878
# [4]	validation_0-auc:0.86310	validation_1-auc:0.81921
# [5]	validation_0-auc:0.86768	validation_1-auc:0.82081
# [6]	validation_0-auc:0.87068	validation_1-auc:0.82173
# [7]	validation_0-auc:0.87477	validation_1-auc:0.82302
# [8]	validation_0-auc:0.88060	validation_1-auc:0.82580
# [9]	validation_0-auc:0.88419	validation_1-auc:0.82544
# [10]	validation_0-auc:0.88875	validation_1-auc:0.82601
# [11]	validation_0-auc:0.89293	validation_1-auc:0.82608
# [12]	validation_0-auc:0.89731	validation_1-auc:0.82607
# [13]	validation_0-auc:0.90161	validation_1-auc:0.82665
# [14]	validation_0-auc:0.90343	validation_1-auc:0.82703
# [15]	validation_0-auc:0.90859	validation_1-auc:0.82458
# [16]	validation_0-auc:0.91102	validation_1-auc:0.82590
# [17]	validation_0-auc:0.91322	validation_1-auc:0.82396
# [18]	validation_0-auc:0.91690	validation_1-auc:0.82544
# [19]	validation_0-auc:0.92046	validation_1-auc:0.82668
# [20]	validation_0-auc:0.92344	validation_1-auc:0.82706
# [21]	validation_0-auc:0.92547	validation_1-auc:0.82696
# [22]	validation_0-auc:0.92911	validation_1-auc:0.82681
# [23]	validation_0-auc:0.93174	validation_1-auc:0.82621
# [24]	validation_0-auc:0.93457	validation_1-auc:0.82696
# [25]	validation_0-auc:0.93715	validation_1-auc:0.82729
# [26]	validation_0-auc:0.93946	validation_1-auc:0.82764
# [27]	validation_0-auc:0.94186	validation_1-auc:0.82689
# [28]	validation_0-auc:0.94323	validation_1-auc:0.82763
# [29]	validation_0-auc:0.94428	validation_1-auc:0.82825
# [30]	validation_0-auc:0.94506	validation_1-auc:0.82842
# [31]	validation_0-auc:0.94598	validation_1-auc:0.82877
# [32]	validation_0-auc:0.94717	validation_1-auc:0.82853
# [33]	validation_0-auc:0.94776	validation_1-auc:0.82830
# [34]	validation_0-auc:0.94900	validation_1-auc:0.82759
# [35]	validation_0-auc:0.95009	validation_1-auc:0.82841
# [36]	validation_0-auc:0.95070	validation_1-auc:0.82814
# [37]	validation_0-auc:0.95151	validation_1-auc:0.82803
# [38]	validation_0-auc:0.95268	validation_1-auc:0.82794
# [39]	validation_0-auc:0.95322	validation_1-auc:0.82738
# [40]	validation_0-auc:0.95385	validation_1-auc:0.82756
# [41]	validation_0-auc:0.95452	validation_1-auc:0.82783
# [42]	validation_0-auc:0.95490	validation_1-auc:0.82780
# [43]	validation_0-auc:0.95538	validation_1-auc:0.82757
# [44]	validation_0-auc:0.95573	validation_1-auc:0.82792
# [45]	validation_0-auc:0.95632	validation_1-auc:0.82760
# [46]	validation_0-auc:0.95688	validation_1-auc:0.82758
# [47]	validation_0-auc:0.95737	validation_1-auc:0.82778
# [48]	validation_0-auc:0.95761	validation_1-auc:0.82759
# [49]	validation_0-auc:0.95788	validation_1-auc:0.82749
# [50]	validation_0-auc:0.95824	validation_1-auc:0.82701
# [51]	validation_0-auc:0.95846	validation_1-auc:0.82696
# [52]	validation_0-auc:0.95913	validation_1-auc:0.82714
# [53]	validation_0-auc:0.95944	validation_1-auc:0.82749
# [54]	validation_0-auc:0.95957	validation_1-auc:0.82761
# [55]	validation_0-auc:0.95983	validation_1-auc:0.82746
# [56]	validation_0-auc:0.96021	validation_1-auc:0.82726
# [57]	validation_0-auc:0.96032	validation_1-auc:0.82675
# [58]	validation_0-auc:0.96064	validation_1-auc:0.82653
# [59]	validation_0-auc:0.96091	validation_1-auc:0.82678
# [60]	validation_0-auc:0.96158	validation_1-auc:0.82672
# [0]	validation_0-auc:0.83409	validation_1-auc:0.79881
# [1]	validation_0-auc:0.82929	validation_1-auc:0.78866
# [2]	validation_0-auc:0.84112	validation_1-auc:0.79873
# [3]	validation_0-auc:0.84583	validation_1-auc:0.80447
# [4]	validation_0-auc:0.84980	validation_1-auc:0.80781
# [5]	validation_0-auc:0.85341	validation_1-auc:0.80915
# [6]	validation_0-auc:0.85630	validation_1-auc:0.81172
# [7]	validation_0-auc:0.85728	validation_1-auc:0.81247
# [8]	validation_0-auc:0.86181	validation_1-auc:0.81563
# [9]	validation_0-auc:0.86402	validation_1-auc:0.81786
# [10]	validation_0-auc:0.86584	validation_1-auc:0.81880
# [11]	validation_0-auc:0.86724	validation_1-auc:0.81931
# [12]	validation_0-auc:0.87036	validation_1-auc:0.82021
# [13]	validation_0-auc:0.87212	validation_1-auc:0.82075
# [14]	validation_0-auc:0.87252	validation_1-auc:0.82122
# [15]	validation_0-auc:0.87239	validation_1-auc:0.81870
# [16]	validation_0-auc:0.87494	validation_1-auc:0.81943
# [17]	validation_0-auc:0.87695	validation_1-auc:0.81898
# [18]	validation_0-auc:0.87760	validation_1-auc:0.82024
# [19]	validation_0-auc:0.87878	validation_1-auc:0.82018
# [20]	validation_0-auc:0.88246	validation_1-auc:0.82129
# [21]	validation_0-auc:0.88215	validation_1-auc:0.81928
# [22]	validation_0-auc:0.88408	validation_1-auc:0.81946
# [23]	validation_0-auc:0.88605	validation_1-auc:0.82045
# [24]	validation_0-auc:0.88733	validation_1-auc:0.82076
# [25]	validation_0-auc:0.89066	validation_1-auc:0.82322
# [26]	validation_0-auc:0.89173	validation_1-auc:0.82367
# [27]	validation_0-auc:0.89436	validation_1-auc:0.82156
# [28]	validation_0-auc:0.89668	validation_1-auc:0.82210
# [29]	validation_0-auc:0.89738	validation_1-auc:0.82292
# [30]	validation_0-auc:0.89781	validation_1-auc:0.82393
# [31]	validation_0-auc:0.89870	validation_1-auc:0.82410
# [32]	validation_0-auc:0.90189	validation_1-auc:0.82351
# [33]	validation_0-auc:0.90299	validation_1-auc:0.82386
# [34]	validation_0-auc:0.90395	validation_1-auc:0.82376
# [35]	validation_0-auc:0.90472	validation_1-auc:0.82325
# [36]	validation_0-auc:0.90569	validation_1-auc:0.82407
# [37]	validation_0-auc:0.90581	validation_1-auc:0.82436
# [38]	validation_0-auc:0.90669	validation_1-auc:0.82420
# [39]	validation_0-auc:0.90796	validation_1-auc:0.82273
# [40]	validation_0-auc:0.90966	validation_1-auc:0.82410
# [41]	validation_0-auc:0.91129	validation_1-auc:0.82484
# [42]	validation_0-auc:0.91228	validation_1-auc:0.82526
# [43]	validation_0-auc:0.91436	validation_1-auc:0.82549
# [44]	validation_0-auc:0.91562	validation_1-auc:0.82610
# [45]	validation_0-auc:0.91751	validation_1-auc:0.82699
# [46]	validation_0-auc:0.91838	validation_1-auc:0.82675
# [47]	validation_0-auc:0.92008	validation_1-auc:0.82702
# [48]	validation_0-auc:0.92074	validation_1-auc:0.82734
# [49]	validation_0-auc:0.92166	validation_1-auc:0.82788
# [50]	validation_0-auc:0.92250	validation_1-auc:0.82697
# [51]	validation_0-auc:0.92385	validation_1-auc:0.82717
# [52]	validation_0-auc:0.92423	validation_1-auc:0.82776
# [53]	validation_0-auc:0.92558	validation_1-auc:0.82783
# [54]	validation_0-auc:0.92546	validation_1-auc:0.82810
# [55]	validation_0-auc:0.92639	validation_1-auc:0.82807
# [56]	validation_0-auc:0.92735	validation_1-auc:0.82790
# [57]	validation_0-auc:0.92773	validation_1-auc:0.82790
# [58]	validation_0-auc:0.92935	validation_1-auc:0.82827
# [59]	validation_0-auc:0.93029	validation_1-auc:0.82846
# [60]	validation_0-auc:0.93113	validation_1-auc:0.82930
# [61]	validation_0-auc:0.93130	validation_1-auc:0.82866
# [62]	validation_0-auc:0.93267	validation_1-auc:0.82893
# [63]	validation_0-auc:0.93388	validation_1-auc:0.82843
# [64]	validation_0-auc:0.93414	validation_1-auc:0.82787
# [65]	validation_0-auc:0.93571	validation_1-auc:0.82866
# [66]	validation_0-auc:0.93673	validation_1-auc:0.82805
# [67]	validation_0-auc:0.93802	validation_1-auc:0.82849
# [68]	validation_0-auc:0.93919	validation_1-auc:0.82794
# [69]	validation_0-auc:0.94013	validation_1-auc:0.82779
# [70]	validation_0-auc:0.94146	validation_1-auc:0.82780
# [71]	validation_0-auc:0.94230	validation_1-auc:0.82777
# [72]	validation_0-auc:0.94240	validation_1-auc:0.82709
# [73]	validation_0-auc:0.94336	validation_1-auc:0.82657
# [74]	validation_0-auc:0.94382	validation_1-auc:0.82636
# [75]	validation_0-auc:0.94442	validation_1-auc:0.82617
# [76]	validation_0-auc:0.94551	validation_1-auc:0.82542
# [77]	validation_0-auc:0.94641	validation_1-auc:0.82600
# [78]	validation_0-auc:0.94665	validation_1-auc:0.82596
# [79]	validation_0-auc:0.94707	validation_1-auc:0.82642
# [80]	validation_0-auc:0.94755	validation_1-auc:0.82636
# [81]	validation_0-auc:0.94805	validation_1-auc:0.82652
# [82]	validation_0-auc:0.94871	validation_1-auc:0.82656
# [83]	validation_0-auc:0.94962	validation_1-auc:0.82614
# [84]	validation_0-auc:0.95002	validation_1-auc:0.82599
# [85]	validation_0-auc:0.95055	validation_1-auc:0.82654
# [86]	validation_0-auc:0.95134	validation_1-auc:0.82653
# [87]	validation_0-auc:0.95201	validation_1-auc:0.82680
# [88]	validation_0-auc:0.95235	validation_1-auc:0.82652
# [89]	validation_0-auc:0.95275	validation_1-auc:0.82657
# [0]	validation_0-auc:0.82532	validation_1-auc:0.80510
# [1]	validation_0-auc:0.81862	validation_1-auc:0.79716
# [2]	validation_0-auc:0.83147	validation_1-auc:0.80816
# [3]	validation_0-auc:0.84210	validation_1-auc:0.81771
# [4]	validation_0-auc:0.84611	validation_1-auc:0.81798
# [5]	validation_0-auc:0.85252	validation_1-auc:0.82348
# [6]	validation_0-auc:0.85498	validation_1-auc:0.82407
# [7]	validation_0-auc:0.85875	validation_1-auc:0.82497
# [8]	validation_0-auc:0.86240	validation_1-auc:0.82563
# [9]	validation_0-auc:0.86504	validation_1-auc:0.82546
# [10]	validation_0-auc:0.86785	validation_1-auc:0.82648
# [11]	validation_0-auc:0.87039	validation_1-auc:0.82684
# [12]	validation_0-auc:0.87264	validation_1-auc:0.82825
# [13]	validation_0-auc:0.87550	validation_1-auc:0.82846
# [14]	validation_0-auc:0.87614	validation_1-auc:0.82856
# [15]	validation_0-auc:0.87594	validation_1-auc:0.82734
# [16]	validation_0-auc:0.87742	validation_1-auc:0.82761
# [17]	validation_0-auc:0.87918	validation_1-auc:0.82707
# [18]	validation_0-auc:0.87953	validation_1-auc:0.82742
# [19]	validation_0-auc:0.88159	validation_1-auc:0.82789
# [20]	validation_0-auc:0.88371	validation_1-auc:0.82775
# [21]	validation_0-auc:0.88410	validation_1-auc:0.82614
# [22]	validation_0-auc:0.88600	validation_1-auc:0.82673
# [23]	validation_0-auc:0.88771	validation_1-auc:0.82655
# [24]	validation_0-auc:0.88958	validation_1-auc:0.82636
# [25]	validation_0-auc:0.89159	validation_1-auc:0.82679
# [26]	validation_0-auc:0.89450	validation_1-auc:0.82710
# [27]	validation_0-auc:0.89657	validation_1-auc:0.82675
# [28]	validation_0-auc:0.89939	validation_1-auc:0.82721
# [29]	validation_0-auc:0.90011	validation_1-auc:0.82755
# [30]	validation_0-auc:0.90138	validation_1-auc:0.82807
# [31]	validation_0-auc:0.90232	validation_1-auc:0.82789
# ...
# [27]	validation_0-auc:0.89089	validation_1-auc:0.83032
# [28]	validation_0-auc:0.89206	validation_1-auc:0.83063
# [29]	validation_0-auc:0.89293	validation_1-auc:0.83126
# [30]	validation_0-auc:0.89419	validation_1-auc:0.83210
# [31]	validation_0-auc:0.89611	validation_1-auc:0.83230
# [32]	validation_0-auc:0.89674	validation_1-auc:0.83204
# [33]	validation_0-auc:0.89793	validation_1-auc:0.83219
# [34]	validation_0-auc:0.89866	validation_1-auc:0.83177
# [35]	validation_0-auc:0.90030	validation_1-auc:0.83191
# [36]	validation_0-auc:0.90095	validation_1-auc:0.83219
# [37]	validation_0-auc:0.90224	validation_1-auc:0.83310
# [38]	validation_0-auc:0.90294	validation_1-auc:0.83260
# [39]	validation_0-auc:0.90344	validation_1-auc:0.83198
# [40]	validation_0-auc:0.90539	validation_1-auc:0.83229
# [41]	validation_0-auc:0.90716	validation_1-auc:0.83296
# [42]	validation_0-auc:0.90757	validation_1-auc:0.83333
# [43]	validation_0-auc:0.90887	validation_1-auc:0.83329
# [44]	validation_0-auc:0.90975	validation_1-auc:0.83335
# [45]	validation_0-auc:0.91073	validation_1-auc:0.83322
# [46]	validation_0-auc:0.91184	validation_1-auc:0.83335
# [47]	validation_0-auc:0.91262	validation_1-auc:0.83320
# [48]	validation_0-auc:0.91309	validation_1-auc:0.83329
# [49]	validation_0-auc:0.91368	validation_1-auc:0.83330
# [50]	validation_0-auc:0.91415	validation_1-auc:0.83337
# [51]	validation_0-auc:0.91481	validation_1-auc:0.83369
# [52]	validation_0-auc:0.91549	validation_1-auc:0.83364
# [53]	validation_0-auc:0.91592	validation_1-auc:0.83345
# [54]	validation_0-auc:0.91626	validation_1-auc:0.83362
# [55]	validation_0-auc:0.91687	validation_1-auc:0.83394
# [56]	validation_0-auc:0.91780	validation_1-auc:0.83347
# [57]	validation_0-auc:0.91825	validation_1-auc:0.83357
# [58]	validation_0-auc:0.91863	validation_1-auc:0.83359
# [59]	validation_0-auc:0.91884	validation_1-auc:0.83382
# [60]	validation_0-auc:0.91925	validation_1-auc:0.83405
# [61]	validation_0-auc:0.91948	validation_1-auc:0.83379
# [62]	validation_0-auc:0.91980	validation_1-auc:0.83388
# [63]	validation_0-auc:0.92010	validation_1-auc:0.83408
# [64]	validation_0-auc:0.92021	validation_1-auc:0.83400
# [65]	validation_0-auc:0.92075	validation_1-auc:0.83415
# [66]	validation_0-auc:0.92141	validation_1-auc:0.83381
# [67]	validation_0-auc:0.92208	validation_1-auc:0.83398
# [68]	validation_0-auc:0.92245	validation_1-auc:0.83417
# [69]	validation_0-auc:0.92299	validation_1-auc:0.83411
# [70]	validation_0-auc:0.92355	validation_1-auc:0.83430
# [71]	validation_0-auc:0.92367	validation_1-auc:0.83454
# [72]	validation_0-auc:0.92377	validation_1-auc:0.83454
# [73]	validation_0-auc:0.92445	validation_1-auc:0.83430
# [74]	validation_0-auc:0.92475	validation_1-auc:0.83429
# [75]	validation_0-auc:0.92513	validation_1-auc:0.83428
# [76]	validation_0-auc:0.92535	validation_1-auc:0.83423
# [77]	validation_0-auc:0.92566	validation_1-auc:0.83438
# [78]	validation_0-auc:0.92580	validation_1-auc:0.83428
# [79]	validation_0-auc:0.92597	validation_1-auc:0.83425
# [80]	validation_0-auc:0.92636	validation_1-auc:0.83399
# [81]	validation_0-auc:0.92643	validation_1-auc:0.83423
# [82]	validation_0-auc:0.92685	validation_1-auc:0.83460
# [83]	validation_0-auc:0.92738	validation_1-auc:0.83450
# [84]	validation_0-auc:0.92753	validation_1-auc:0.83469
# [85]	validation_0-auc:0.92792	validation_1-auc:0.83480
# [86]	validation_0-auc:0.92822	validation_1-auc:0.83486
# [87]	validation_0-auc:0.92840	validation_1-auc:0.83499
# [88]	validation_0-auc:0.92882	validation_1-auc:0.83513
# [89]	validation_0-auc:0.92917	validation_1-auc:0.83525
# [90]	validation_0-auc:0.92943	validation_1-auc:0.83531
# [91]	validation_0-auc:0.92952	validation_1-auc:0.83535
# [92]	validation_0-auc:0.92970	validation_1-auc:0.83524
# [93]	validation_0-auc:0.92996	validation_1-auc:0.83549
# [94]	validation_0-auc:0.93016	validation_1-auc:0.83546
# [95]	validation_0-auc:0.93025	validation_1-auc:0.83549
# [96]	validation_0-auc:0.93034	validation_1-auc:0.83545
# [97]	validation_0-auc:0.93050	validation_1-auc:0.83549
# [98]	validation_0-auc:0.93068	validation_1-auc:0.83551
# [99]	validation_0-auc:0.93084	validation_1-auc:0.83546
# [0]	validation_0-auc:0.82590	validation_1-auc:0.80061
# [1]	validation_0-auc:0.82062	validation_1-auc:0.79225
# [2]	validation_0-auc:0.83439	validation_1-auc:0.80304
# [3]	validation_0-auc:0.84028	validation_1-auc:0.80845
# [4]	validation_0-auc:0.84500	validation_1-auc:0.81201
# [5]	validation_0-auc:0.84699	validation_1-auc:0.81112
# [6]	validation_0-auc:0.84888	validation_1-auc:0.81373
# [7]	validation_0-auc:0.85189	validation_1-auc:0.81477
# [8]	validation_0-auc:0.85409	validation_1-auc:0.81653
# [9]	validation_0-auc:0.85676	validation_1-auc:0.81713
# [10]	validation_0-auc:0.86011	validation_1-auc:0.82015
# [11]	validation_0-auc:0.86325	validation_1-auc:0.82073
# [12]	validation_0-auc:0.86608	validation_1-auc:0.82170
# [13]	validation_0-auc:0.87085	validation_1-auc:0.82275
# [14]	validation_0-auc:0.87181	validation_1-auc:0.82436
# [15]	validation_0-auc:0.87374	validation_1-auc:0.82344
# [16]	validation_0-auc:0.87404	validation_1-auc:0.82193
# [17]	validation_0-auc:0.87465	validation_1-auc:0.82066
# [18]	validation_0-auc:0.87686	validation_1-auc:0.82176
# [19]	validation_0-auc:0.87907	validation_1-auc:0.82336
# [20]	validation_0-auc:0.88165	validation_1-auc:0.82616
# [21]	validation_0-auc:0.88174	validation_1-auc:0.82339
# [22]	validation_0-auc:0.88470	validation_1-auc:0.82665
# [23]	validation_0-auc:0.88747	validation_1-auc:0.82800
# [24]	validation_0-auc:0.88910	validation_1-auc:0.82944
# [25]	validation_0-auc:0.89148	validation_1-auc:0.83015
# [26]	validation_0-auc:0.89381	validation_1-auc:0.83048
# [27]	validation_0-auc:0.89552	validation_1-auc:0.83036
# [28]	validation_0-auc:0.89698	validation_1-auc:0.82897
# [29]	validation_0-auc:0.89835	validation_1-auc:0.83003
# [30]	validation_0-auc:0.89935	validation_1-auc:0.83086
# [31]	validation_0-auc:0.90040	validation_1-auc:0.83090
# [32]	validation_0-auc:0.90196	validation_1-auc:0.82986
# [33]	validation_0-auc:0.90290	validation_1-auc:0.82990
# [34]	validation_0-auc:0.90394	validation_1-auc:0.82953
# [35]	validation_0-auc:0.90500	validation_1-auc:0.82861
# [36]	validation_0-auc:0.90638	validation_1-auc:0.82920
# [37]	validation_0-auc:0.90742	validation_1-auc:0.82861
# [38]	validation_0-auc:0.90818	validation_1-auc:0.82813
# [39]	validation_0-auc:0.90874	validation_1-auc:0.82742
# [40]	validation_0-auc:0.91000	validation_1-auc:0.82835
# [41]	validation_0-auc:0.91124	validation_1-auc:0.82829
# [42]	validation_0-auc:0.91187	validation_1-auc:0.82831
# [43]	validation_0-auc:0.91305	validation_1-auc:0.82853
# [44]	validation_0-auc:0.91380	validation_1-auc:0.82961
# [45]	validation_0-auc:0.91474	validation_1-auc:0.82975
# [46]	validation_0-auc:0.91507	validation_1-auc:0.82952
# [47]	validation_0-auc:0.91580	validation_1-auc:0.82957
# [48]	validation_0-auc:0.91622	validation_1-auc:0.82961
# [49]	validation_0-auc:0.91643	validation_1-auc:0.82938
# [50]	validation_0-auc:0.91699	validation_1-auc:0.82928
# [51]	validation_0-auc:0.91719	validation_1-auc:0.82927
# [52]	validation_0-auc:0.91748	validation_1-auc:0.82960
# [53]	validation_0-auc:0.91790	validation_1-auc:0.82927
# [54]	validation_0-auc:0.91816	validation_1-auc:0.82930
# [55]	validation_0-auc:0.91821	validation_1-auc:0.82934
# [56]	validation_0-auc:0.91849	validation_1-auc:0.82906
# [57]	validation_0-auc:0.91863	validation_1-auc:0.82914
# [58]	validation_0-auc:0.91888	validation_1-auc:0.82919
# [59]	validation_0-auc:0.91901	validation_1-auc:0.82916
# [60]	validation_0-auc:0.91917	validation_1-auc:0.82911
# [61]	validation_0-auc:0.91923	validation_1-auc:0.82898
# [0]	validation_0-auc:0.81908	validation_1-auc:0.80449
# [1]	validation_0-auc:0.81936	validation_1-auc:0.79842
# [2]	validation_0-auc:0.83506	validation_1-auc:0.81696
# [3]	validation_0-auc:0.84372	validation_1-auc:0.82128
# [4]	validation_0-auc:0.84971	validation_1-auc:0.82301
# [5]	validation_0-auc:0.85215	validation_1-auc:0.82027
# [6]	validation_0-auc:0.85591	validation_1-auc:0.82495
# [7]	validation_0-auc:0.85950	validation_1-auc:0.82709
# [8]	validation_0-auc:0.86301	validation_1-auc:0.82982
# [9]	validation_0-auc:0.86366	validation_1-auc:0.82781
# [10]	validation_0-auc:0.86543	validation_1-auc:0.82876
# [11]	validation_0-auc:0.86883	validation_1-auc:0.82870
# [12]	validation_0-auc:0.87084	validation_1-auc:0.82894
# [13]	validation_0-auc:0.87289	validation_1-auc:0.82846
# [14]	validation_0-auc:0.87474	validation_1-auc:0.82861
# [15]	validation_0-auc:0.87644	validation_1-auc:0.82790
# [16]	validation_0-auc:0.87694	validation_1-auc:0.82642
# [17]	validation_0-auc:0.87746	validation_1-auc:0.82412
# [18]	validation_0-auc:0.87964	validation_1-auc:0.82595
# [19]	validation_0-auc:0.88252	validation_1-auc:0.82773
# [20]	validation_0-auc:0.88495	validation_1-auc:0.82913
# [21]	validation_0-auc:0.88468	validation_1-auc:0.82781
# [22]	validation_0-auc:0.88674	validation_1-auc:0.82920
# [23]	validation_0-auc:0.88912	validation_1-auc:0.82956
# [24]	validation_0-auc:0.89221	validation_1-auc:0.82995
# [25]	validation_0-auc:0.89403	validation_1-auc:0.83075
# [26]	validation_0-auc:0.89607	validation_1-auc:0.83080
# [27]	validation_0-auc:0.89701	validation_1-auc:0.82995
# [28]	validation_0-auc:0.89802	validation_1-auc:0.82942
# [29]	validation_0-auc:0.89906	validation_1-auc:0.82983
# [30]	validation_0-auc:0.90085	validation_1-auc:0.83139
# [31]	validation_0-auc:0.90251	validation_1-auc:0.83169
# [32]	validation_0-auc:0.90400	validation_1-auc:0.83076
# [33]	validation_0-auc:0.90543	validation_1-auc:0.83184
# [34]	validation_0-auc:0.90693	validation_1-auc:0.83193
# [35]	validation_0-auc:0.90737	validation_1-auc:0.83118
# [36]	validation_0-auc:0.90845	validation_1-auc:0.83183
# [37]	validation_0-auc:0.90887	validation_1-auc:0.83144
# [38]	validation_0-auc:0.91015	validation_1-auc:0.83053
# [39]	validation_0-auc:0.91044	validation_1-auc:0.83001
# [40]	validation_0-auc:0.91169	validation_1-auc:0.83082
# [41]	validation_0-auc:0.91308	validation_1-auc:0.83138
# [42]	validation_0-auc:0.91365	validation_1-auc:0.83229
# [43]	validation_0-auc:0.91414	validation_1-auc:0.83256
# [44]	validation_0-auc:0.91492	validation_1-auc:0.83282
# [45]	validation_0-auc:0.91571	validation_1-auc:0.83320
# [46]	validation_0-auc:0.91618	validation_1-auc:0.83347
# [47]	validation_0-auc:0.91683	validation_1-auc:0.83374
# [48]	validation_0-auc:0.91731	validation_1-auc:0.83388
# [49]	validation_0-auc:0.91773	validation_1-auc:0.83377
# [50]	validation_0-auc:0.91814	validation_1-auc:0.83372
# [51]	validation_0-auc:0.91855	validation_1-auc:0.83392
# [52]	validation_0-auc:0.91906	validation_1-auc:0.83363
# [53]	validation_0-auc:0.91968	validation_1-auc:0.83344
# [54]	validation_0-auc:0.91988	validation_1-auc:0.83349
# [55]	validation_0-auc:0.92037	validation_1-auc:0.83324
# [56]	validation_0-auc:0.92088	validation_1-auc:0.83334
# [57]	validation_0-auc:0.92115	validation_1-auc:0.83345
# [58]	validation_0-auc:0.92208	validation_1-auc:0.83390
# [59]	validation_0-auc:0.92232	validation_1-auc:0.83397
#  12%|█▏        | 6/50 [27:29<3:21:35, 274.90s/trial, best loss: -0.8365077524183202]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-c10b2b73b6ce> in <cell line: 5>()
#       3 trials=Trials()
#       4
# ----> 5 best=fmin(fn=objective_func,
#       6           space=xgb_search_space,
#       7           algo=tpe.suggest,
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     538
#     539     if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540         return trials.fmin(
#     541             fn,
#     542             space,
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/base.py in fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     669         from .fmin import fmin
#     670
# --> 671         return fmin(
#     672             fn,
#     673             space,
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     584
#     585     # next line is where the fmin is actually executed
# --> 586     rval.exhaust()
#     587
#     588     if return_argmin:
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in exhaust(self)
#     362     def exhaust(self):
#     363         n_done = len(self.trials)
# --> 364         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365         self.trials.refresh()
#     366         return self
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in run(self, N, block_until_done)
#     298                 else:
#     299                     # -- loop over trials and do the jobs directly
# --> 300                     self.serial_evaluate()
#     301
#     302                 self.trials.refresh()
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in serial_evaluate(self, N)
#     176                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177                 try:
# --> 178                     result = self.domain.evaluate(spec, ctrl)
#     179                 except Exception as e:
#     180                     logger.error("job exception: %s" % str(e))
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/base.py in evaluate(self, config, ctrl, attach_attachments)
#     890                 print_node_on_error=self.rec_eval_print_node_on_error,
#     891             )
# --> 892             rval = self.fn(pyll_rval)
#     893
#     894         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-47-9eb5a2301623> in objective_func(search_space)
#      16     X_val, y_val=X_train.iloc[val_index],y_train.iloc[val_index]
#      17
# ---> 18     xgb_clf.fit(X_tr, y_tr, early_stopping_rounds=30, eval_metric="auc",
#      19                 eval_set=[(X_tr,y_tr),(X_val,y_val)])
#      20
#
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     504         for k, arg in zip(sig.parameters, args):
#     505             kwargs[k] = arg
# --> 506         return f(**kwargs)
#     507
#     508     return inner_f
#
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1248         )
#    1249
# -> 1250         self._Booster = train(
#    1251             params,
#    1252             train_dmatrix,
#
# /usr/local/lib/python3.10/dist-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     186     Booster : a trained booster model
#     187     """
# --> 188     bst = _train_internal(params, dtrain,
#     189                           num_boost_round=num_boost_round,
#     190                           evals=evals,
#
# /usr/local/lib/python3.10/dist-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, evals_result, maximize, verbose_eval, early_stopping_rounds)
#      79         if callbacks.before_iteration(bst, i, dtrain, evals):
#      80             break
# ---> 81         bst.update(dtrain, i, obj)
#      82         if callbacks.after_iteration(bst, i, dtrain, evals):
#      83             break
#
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1678
#    1679         if fobj is None:
# -> 1680             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1681                                                     ctypes.c_int(iteration),
#    1682                                                     dtrain.handle))
#
# KeyboardInterrupt:

# %%
xbg_XBGClassifier(n_estimators=500, learning_rate=round(best['learning_rate'],5),
                  max_depth=int(best['max_depth']),
                  min_child_weight=int(best['min_child_weight']),
                  colsample_bytree=round(best['colsample_bytree'],5)
                  )

xgb_clf.fit(X_train,y_tr,early_stopping_rounds=100,
            eval_metric="auc", eval_set=[(X_tr, y_tr),(X_val,y_val)])

xgb_roc_score=roc_auc_score(y_test, xgb_clf.predict_proba(X_test)[:,1])
print('ROC AUC: {0:.4f}'.format(xgb_roc_score))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-0d5b8250ba0f> in <cell line: 1>()
# ----> 1 xbg_XBGClassifier(n_estimators=500, learning_rate=round(best['learning_rate'],5),
#       2                   max_depth=int(best['max_depth']),
#       3                   min_child_weight=int(best['min_child_weight']),
#       4                   colsample_bytree=round(best['colsample_bytree'],5)
#       5                   )
#
# NameError: name 'xbg_XBGClassifier' is not defined

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig,ax=plt.subplots(1,1,figsize=(10,8))
plot_importance(xgb_clf, ax=ax,max_num_features=20, height=0.4)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>
